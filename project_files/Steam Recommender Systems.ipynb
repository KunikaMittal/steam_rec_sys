# %% [markdown]
# # Team Project 7
# ### Fall 2020 - UCSD Steam Recommender Systems Dataset
#
# - Steven Louie
# - Kunika Mittal
# - Pranav Patil

# %%
# importing libraries
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import operator
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Process data files

# %%
# function used to process the data files
def eval_file(file):
    f = open(file, "r", encoding="utf-8")
    lst = []
    for line in f:
        obj = eval(line)
        lst.append(obj)
    json.dumps(lst)
    return lst

# %%
# process data files into respective variables
bundle_data = eval_file("../data/bundle_data.json")
users_items = eval_file("../data/australian_users_items.json")
steam_games = eval_file("../data/steam_games.json")

# %%
# create a dataframe from bundle_data that consists of all the games within each bundle
bundle_df = json_normalize(bundle_data, "items", ["bundle_final_price", "bundle_url", "bundle_price", "bundle_name", "bundle_id"])
# load games data in as a dataframe
steam_games_df = pd.DataFrame(data=steam_games)
bundle_data_df = pd.DataFrame(data=bundle_data)

# %% [markdown]
# # Data Analysis
# Exploratory Data Analysis has been done to understand the datasets better. Since we have three different datasets that we are working with, it is mandatory to know what information would be useful while preprocessing the data.
#
# #### Steam Games Dataset ####
# The steam games dataset gives us the information about the different games available on the website. There are some of the features in the dataset that are not useful to us for recommending the individual games and building the customised bundles for the user. We plan to drop them all while doing data pre processing.

# %%
steam_games_df.head()
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3              彼岸领域                        [Action, Adventure, Casual]
# 4               NaN                                                NaN
#
#                   app_name                    title  \
# 0      Lost Summoner Kitty      Lost Summoner Kitty
# 1                Ironbound                Ironbound
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 3                  弹炸人2222                  弹炸人2222
# 4            Log Challenge                      NaN
#
#                                                  url release_date  \
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2  http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3     http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4  http://store.steampowered.com/app/773570/Log_C...          NaN
#
#                                                 tags  discount_price  \
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2  [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                        [Action, Adventure, Casual]            0.83
# 4                    [Action, Indie, Casual, Sports]            1.79
#
#                                          reviews_url  \
# 0  http://steamcommunity.com/app/761140/reviews/?...
# 1  http://steamcommunity.com/app/643980/reviews/?...
# 2  http://steamcommunity.com/app/670290/reviews/?...
# 3  http://steamcommunity.com/app/767400/reviews/?...
# 4  http://steamcommunity.com/app/773570/reviews/?...
#
#                                                specs         price  \
# 0                                    [Single-player]          4.99
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                    [Single-player]          0.99
# 4  [Single-player, Full controller support, HTC V...          2.99
#
#    early_access      id         developer        sentiment metascore
# 0         False  761140         Kotoshiro              NaN       NaN
# 1         False  643980  Secret Level SRL  Mostly Positive       NaN
# 2         False  670290      Poolians.com  Mostly Positive       NaN
# 3         False  767400              彼岸领域              NaN       NaN
# 4         False  773570               NaN              NaN       NaN

# %% [markdown]
# #### Finding out the top publishers of games in the dataset ####
# There are more than 8000 publishers on the platform but majority of the games have been published by the top 5 publishers who amount up to about 20% of the games available in the dataset.

# %%
steam_games_df.publisher.value_counts().nlargest(5).plot.bar()

# %%
steam_games_df.publisher.value_counts()
# Out:
# Ubisoft                                  385
# Dovetail Games - Trains                  360
# Degica                                   286
# Paradox Interactive                      271
# SEGA                                     251
#                                         ...
# Genetix Studio                             1
# Pixel Maverick Games                       1
# Studio Forge Ltd                           1
# Asmodee Digital, Z-Man Games               1
# Gamestarters Publisher, Gamestarter's      1
# Name: publisher, Length: 8239, dtype: int64

# %% [markdown]
# #### Bundle Games Dataset ####
#
# The bundles games dataset has been evaluated to understand the revenue modeling around the bundles. As the graph and the total value count of every discount shown below, majority of the games are discounted upto 25% while the highest discount offered is 94%. This information can be used to build customised bundles for the users offering them maximum discounts.

# %%
bundle_data_df.head()
# Out:
#   bundle_final_price                                         bundle_url  \
# 0             $66.46  http://store.steampowered.com/bundle/450/?utm_...
# 1             $20.15  http://store.steampowered.com/bundle/1473/?utm...
# 2             $20.15  http://store.steampowered.com/bundle/1474/?utm...
# 3             $15.17  http://store.steampowered.com/bundle/1437/?utm...
# 4             $20.15  http://store.steampowered.com/bundle/1466/?utm...
#
#   bundle_price                              bundle_name bundle_id  \
# 0       $73.86             Dharker Studio 2015 Complete       450
# 1       $25.87  Naruto Shippuden Uncut Season 4, Vol. 3      1473
# 2       $25.87  Naruto Shippuden Uncut Season 4, Vol. 4      1474
# 3       $25.35      Pixel Puzzles Ultimate: Starter Kit      1437
# 4       $25.87  Naruto Shippuden Uncut Season 4, Vol. 1      1466
#
#                                                items bundle_discount
# 0  [{'genre': 'Adventure, Indie, RPG', 'item_id':...             10%
# 1  [{'genre': '', 'item_id': '528360', 'discounte...             22%
# 2  [{'genre': '', 'item_id': '528380', 'discounte...             22%
# 3  [{'genre': 'Casual, Free to Play, Indie, Simul...             40%
# 4  [{'genre': '', 'item_id': '527830', 'discounte...             22%

# %%
bundle_data_df.bundle_discount.value_counts().nlargest(5).plot.bar()

# %%
bundle_data_df.bundle_discount.value_counts()
# Out:
# 10%     108
# 20%      90
# 25%      82
# 15%      55
# 30%      40
# 50%      34
# 0%       29
# 40%      25
# 33%      19
# 35%      11
# 22%      10
# 5%        8
# 16%       6
# 45%       6
# 60%       5
# 67%       5
# 17%       5
# 28%       4
# 13%       4
# 7%        4
# 80%       4
# 34%       3
# 6%        3
# 65%       3
# 11%       3
# 29%       3
# 75%       2
# 23%       2
# 92%       2
# 62%       2
# 8%        2
# 12%       2
# 89%       2
# 48%       2
# 18%       2
# 57%       2
# 39%       2
# 38%       2
# 37%       2
# 14%       2
# 49%       1
# 7.5%      1
# 42%       1
# 86%       1
# 32%       1
# 46%       1
# 85%       1
# 27%       1
# 9%        1
# 21%       1
# 41%       1
# 26%       1
# 64%       1
# 36%       1
# 87%       1
# 90%       1
# 61%       1
# 55%       1
# Name: bundle_discount, dtype: int64

# %% [markdown]
# At this point we know who are the top publishers in our data set (Ubisoft, Dovetail Games - Trains, Degica, Paradox Interactive, SEGA) and an analysis of the marketplace (majority of the games are discounted upto 25%), we have some context of the data we will be using.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# For data preprocessing, we will be cleaning up the datasets by removing any empty entries in the datasets. This will allow us to build a more effective recommender's system using data with non-empty entries.

# %% [markdown]
# We will be removing any games in the bundle's data that have no genre. Games that have no genre are not playable games and are probably media data such as movies, videos, songs, etc. These types of data will not be useful in our implementation, so it is best to filter them out.

# %%
# function used to remove any games in the bundle's data that have no genre
def clean_bundle_data(df):    
    clean_bundle_df = df[df["genre"]!=""]
    return clean_bundle_df

# %% [markdown]
# Some of the features in the steam games dataframe are duplicates of other features. For instance, 'app_name' and 'title' are two features in the dataset that mean the same thing and have the same value. Same goes for 'tags' where 'genres' mean and have the same value in the dataset. These extra features are of no use to us and will only make it harder to understand the dataset.

# %%
# remove unwanted features in steam games dataframe
def clean_games_data():
    steam_games_df.drop(labels=["app_name", "tags", "metascore"], axis=1, inplace=True)
    steam_games_df.dropna(subset=["title", "genres"], inplace=True)

# %% [markdown]
# Users that have no game history have no use in our recommender's system implementation because these users have nothing to offer, so it is best to filter them out.

# %%
# function used to remove any users that have not played any games
def remove_idle_users():
    # loop through users data and remove users that are idle
    for i in users_items:
        if i["items_count"]==0:
            users_items.remove(i)

# %%
# function used to perform the aforementioned preprocessing techniques
def perform_data_preprocessing():
    clean_games_data()
    remove_idle_users()
    np.random.shuffle(users_items)

# %% [markdown]
# In the user-items dataset, there are users that have played hundreds and hundreds of games but not all data are useful and meaningful to us. For instance, users that might've downloaded a game but have not played or played long enough to show any interest in the game are not useful because users that like to play a specific type of game or game will show more playing time. Therefore, this function is dedicated to filter out any items in the active user's items list that have little to no play time at all because noisy data will only skew and affect our results in a negative way.

# %%
# function used to filter out any games user has played with little to no playing time at all
# returns a dataframe of relevant games user has played
def filter_by_playtime(user_id, playtime):
    user_data = {}
    
    for user in users_items:
        if user["user_id"]==user_id:
            user_data = user
            break
    
    filtered_df = json_normalize(user_data, "items", ["user_id", "steam_id", "user_url"])
    filtered_df = filtered_df[filtered_df["playtime_forever"] > playtime]
    
    return filtered_df, user_data

# %%
# function used to extract every genre in every bundle
def extract_genres_data_from_bundles(bundle_df): 
    
    clean_bundle_df = clean_bundle_data(bundle_df)
    
    # uses an object to hold key value pairs
    # keys will be bundle id and values will be genres of games inside that bundle
    filter_genre_from_bundle = {}
    
    # loop through every bundle and extract genres
    for id_ in clean_bundle_df["bundle_id"].unique():
        genres_list = []
        for genres in clean_bundle_df[clean_bundle_df["bundle_id"]==id_]["genre"]:
            for genre in genres.split(", "):
                if genre not in genres_list:
                    genres_list.append(genre)
        filter_genre_from_bundle[id_] = genres_list
        
    return filter_genre_from_bundle

# %%
perform_data_preprocessing()

# %%
steam_games_df.head()
# Out:
#              publisher                                             genres  \
# 0            Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1     Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2         Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                 彼岸领域                        [Action, Adventure, Casual]
# 5  Trickjump Games Ltd                    [Action, Adventure, Simulation]
#
#                      title                                                url  \
# 0      Lost Summoner Kitty  http://store.steampowered.com/app/761140/Lost_...
# 1                Ironbound  http://store.steampowered.com/app/643980/Ironb...
# 2  Real Pool 3D - Poolians  http://store.steampowered.com/app/670290/Real_...
# 3                  弹炸人2222     http://store.steampowered.com/app/767400/2222/
# 5    Battle Royale Trainer  http://store.steampowered.com/app/772540/Battl...
#
#   release_date  discount_price  \
# 0   2018-01-04            4.49
# 1   2018-01-04             NaN
# 2   2017-07-24             NaN
# 3   2017-12-07            0.83
# 5   2018-01-04             NaN
#
#                                          reviews_url  \
# 0  http://steamcommunity.com/app/761140/reviews/?...
# 1  http://steamcommunity.com/app/643980/reviews/?...
# 2  http://steamcommunity.com/app/670290/reviews/?...
# 3  http://steamcommunity.com/app/767400/reviews/?...
# 5  http://steamcommunity.com/app/772540/reviews/?...
#
#                                                specs         price  \
# 0                                    [Single-player]          4.99
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                    [Single-player]          0.99
# 5                [Single-player, Steam Achievements]          3.99
#
#    early_access      id            developer        sentiment
# 0         False  761140            Kotoshiro              NaN
# 1         False  643980     Secret Level SRL  Mostly Positive
# 2         False  670290         Poolians.com  Mostly Positive
# 3         False  767400                 彼岸领域              NaN
# 5         False  772540  Trickjump Games Ltd            Mixed

# %%
all_bundles_genres_data = extract_genres_data_from_bundles(bundle_df)

# %% [markdown]
# The user that we will be performing the use cases on is a user who has played some games on the Steam platform whose user id will be shown below. Our recommender's system does not worry about users that haven't played any games and only focuses on the ones that have. Again this is a random user in the users dataset that has some games logged on the Steam platform. The following outputs of each use case will be based off of this user.

# %%
users_items[0]["user_id"]
# Out:
# '76561198074419128'

# %%
filtered_playtime_df, active_user_data = filter_by_playtime(users_items[0]["user_id"], 60)

# %% [markdown]
# # Use Case #1: Recommend bundles to a user based on most played genres

# %% [markdown]
# ![Image of Steam Library](https://i.imgur.com/LvSswTJ.jpg)

# %% [markdown]
# To get a better understanding of how this use case works, the image above is an image of a steam user's library and content inside the red circle are the list of user's games. Thus, the first use case of our project is using a content-based recommendation system to recommend bundles to the active user based on the user's top played game genres. This is similar to a user logging into Steam and seeing a list of recommendations based on the history of games that user has played. We are only recommending bundles that are most similar to the active user because this would improve user experience by recommending bundles that contain games that user has previously shown interest in playing.

# %%
# function used to calculate the cosine similarity between two given vectors
def cosine_sim(vector1, vector2):
    
    # holds the cosine similarity score of the two vectors
    cos = 0
    
    # used to store 0s or 1s for respective vector
    lst1 = []
    lst2 = []
    
    # gets the elements that appear in both vectors and store them in a list
    vector = list(set().union(vector1, vector2))
    
    # for every element in both vectors, append 1 to lst1 if element appears in vectors otherwise append 0
    # repeat this for both vectors
    for i in vector:
        if i in vector1:
            lst1.append(1)
        else:
            lst1.append(0)    
        if i in vector2:
            lst2.append(1)
        else:
            lst2.append(0)
        cos += lst1[-1]*lst2[-1]
    
    # used to hold the magnitude of cosine which is the multiple of the length vectors
    magnitude = float((sum(lst1)*sum(lst2))**0.5)
    
    # only calculate cosine similarity if magnitude/denominator is not zero
    if magnitude != 0:
        cos = cos / magnitude
    
    return cos, magnitude

# %%
# function used to calculate the jaccard similarity between two vectors
def jaccard_sim(vector1, vector2):
    jac = 0
    
    intersection = list(set(vector1).intersection(vector2))
    union = list(set().union(vector1, vector2))
    
    return float(len(intersection))/float(len(union))

# %% [markdown]
# The function takes the previously filtered dataframe that has filtered out games that user have not played or have little play time to extract every type of genre of games user has played. This will return a list of sorted genres in descending order which will later be used to extract only the top genres user has played.

# %%
# function used to extract every genre that user has played from the previously filtered dataframe
def get_all_genres_by_user(user):
    genre_count = {}
    for index, row in user.iterrows():
        if steam_games_df[steam_games_df["id"]==row["item_id"]].index.any()==True:
            game_genres = steam_games_df[steam_games_df["id"]==row["item_id"]]["genres"].values[0]
            for genre in game_genres:
                if genre not in genre_count:
                    genre_count[genre] = 1
                else:
                    genre_count[genre] = genre_count[genre] + 1

    return sorted(genre_count.items(), key=operator.itemgetter(1), reverse=True)

# %%
# function used to get the top genres user has played
# this will give us a better understanding of what type of games user likes to play and only recommend relevant games
def parse_genres(genres):
    lst = []
    for genre in genres[:math.ceil(len(genres)*.6)]:
        lst.append(genre[0])
    return lst

# %% [markdown]
# In order to recommend relevant bundles to the user, we have to calculate the cosine similarity between user's top genres played and genres of each bundle. This function will return a list of sorted bundles in descending order which will be used later to filter out and recommend the most similar bundles based on user's top played genres.

# %%
# function used to calculate the similarity scores between user's top genres played and genres of each bundle
def get_bundle_similarity_scores(user_genres, all_bundles_genres_data):
    cos_sim = {}
    jac_sim = {}
    for id_ in list(all_bundles_genres_data.keys()):
        bundle_genres = all_bundles_genres_data[id_]

        cos,_ = cosine_sim(user_genres, bundle_genres)
        jac = jaccard_sim(user_genres, bundle_genres)
        
        cos_sim[id_] = cos
        jac_sim[id_] = jac
    
    return sorted(cos_sim.items(), key=operator.itemgetter(1), reverse=True), sorted(jac_sim.items(), key=operator.itemgetter(1), reverse=True)

# %%
all_user_genres = get_all_genres_by_user(filtered_playtime_df)

# %%
top_rated_genres = parse_genres(all_user_genres)

# %% [markdown]
# Here is a list of the top played genres by the active user. This output will be used to get the most similar bundles to the top played genres by the user. This is done to cater to the active user's preferences and improve user experience by recommending bundles that are most similar to top played genres by the user.

# %%
top_rated_genres
# Out:
# ['Action',
#  'Indie',
#  'RPG',
#  'Free to Play',
#  'Adventure',
#  'Strategy',
#  'Massively Multiplayer',
#  'Casual']

# %%
bundle_cosine_sims, bundle_jaccard_sims = get_bundle_similarity_scores(top_rated_genres, all_bundles_genres_data)

# %% [markdown]
# The following results are the cosine similarity scores of the bundles data and are in the form of a tuple (bundle id, cosine similarity score) and the bundles in descending order and will be used to get the top k bundles to recommend to the users.

# %%
bundle_cosine_sims
# Out:
# [('808', 0.875),
#  ('663', 0.875),
#  ('923', 0.8660254037844387),
#  ('1206', 0.8660254037844387),
#  ('398', 0.8660254037844387),
#  ('948', 0.8249579113843055),
#  ('396', 0.8017837257372732),
#  ('825', 0.8017837257372732),
#  ('929', 0.8017837257372732),
#  ('505', 0.8017837257372732),
#  ('364', 0.8017837257372732),
#  ('399', 0.8017837257372732),
#  ('482', 0.8017837257372732),
#  ('957', 0.8017837257372732),
#  ('804', 0.8017837257372732),
#  ('403', 0.8017837257372732),
#  ('934', 0.8017837257372732),
#  ('542', 0.8017837257372732),
#  ('331', 0.8017837257372732),
#  ('356', 0.8017837257372732),
#  ('450', 0.7905694150420948),
#  ('1482', 0.7905694150420948),
#  ('279', 0.7905694150420948),
#  ('347', 0.7905694150420948),
#  ('850', 0.7905694150420948),
#  ('977', 0.7905694150420948),
#  ('611', 0.7905694150420948),
#  ('1250', 0.7905694150420948),
#  ('434', 0.7905694150420948),
#  ('990', 0.7905694150420948),
#  ('1056', 0.7905694150420948),
#  ('1054', 0.7905694150420948),
#  ('1055', 0.7905694150420948),
#  ('1040', 0.7905694150420948),
#  ('949', 0.7905694150420948),
#  ('920', 0.7905694150420948),
#  ('854', 0.7905694150420948),
#  ('728', 0.7905694150420948),
#  ('665', 0.7905694150420948),
#  ('153', 0.7905694150420948),
#  ('260', 0.7905694150420948),
#  ('350', 0.7905694150420948),
#  ('433', 0.7905694150420948),
#  ('476', 0.7905694150420948),
#  ('484', 0.7905694150420948),
#  ('514', 0.7905694150420948),
#  ('803', 0.75),
#  ('813', 0.75),
#  ('1021', 0.75),
#  ('833', 0.75),
#  ('425', 0.75),
#  ('225', 0.75),
#  ('565', 0.75),
#  ('1440', 0.7216878364870323),
#  ('1441', 0.7216878364870323),
#  ('953', 0.7216878364870323),
#  ('501', 0.7216878364870323),
#  ('801', 0.7216878364870323),
#  ('1132', 0.7216878364870323),
#  ('1116', 0.7216878364870323),
#  ('1053', 0.7216878364870323),
#  ('824', 0.7216878364870323),
#  ('760', 0.7216878364870323),
#  ('569', 0.7216878364870323),
#  ('646', 0.7216878364870323),
#  ('746', 0.7216878364870323),
#  ('623', 0.7216878364870323),
#  ('616', 0.7216878364870323),
#  ('332', 0.7216878364870323),
#  ('339', 0.7216878364870323),
#  ('432', 0.7216878364870323),
#  ('436', 0.7216878364870323),
#  ('457', 0.7216878364870323),
#  ('460', 0.7216878364870323),
#  ('511', 0.7216878364870323),
#  ('580', 0.7071067811865476),
#  ('1404', 0.7071067811865475),
#  ('1406', 0.7071067811865475),
#  ('1407', 0.7071067811865475),
#  ('1390', 0.7071067811865475),
#  ('498', 0.7071067811865475),
#  ('1378', 0.7071067811865475),
#  ('982', 0.7071067811865475),
#  ('622', 0.7071067811865475),
#  ('653', 0.7071067811865475),
#  ('449', 0.6123724356957946),
#  ('487', 0.6123724356957946),
#  ('488', 0.6123724356957946),
#  ('503', 0.6123724356957946),
#  ('535', 0.6123724356957946),
#  ('540', 0.6123724356957946),
#  ('547', 0.6123724356957946),
#  ('578', 0.6123724356957946),
#  ('586', 0.6123724356957946),
#  ('594', 0.6123724356957946),
#  ('1437', 0.5773502691896258),
#  ('1005', 0.5773502691896258),
#  ('1007', 0.5773502691896258),
#  ('560', 0.5773502691896258),
#  ('1143', 0.5773502691896258),
#  ('984', 0.5773502691896258),
#  ('1008', 0.5773502691896258),
#  ('1468', 0.5345224838248488),
#  ('1137', 0.5345224838248488),
#  ('413', 0.5345224838248488),
#  ('844', 0.5345224838248488),
#  ('845', 0.5345224838248488),
#  ('1477', 0.5303300858899106),
#  ('419', 0.5303300858899106),
#  ('1385', 0.5303300858899106),
#  ('1356', 0.5303300858899106),
#  ('1361', 0.5303300858899106),
#  ('1209', 0.5303300858899106),
#  ('1100', 0.5303300858899106),
#  ('507', 0.5303300858899106),
#  ('539', 0.5303300858899106),
#  ('614', 0.5303300858899106),
#  ('526', 0.5303300858899106),
#  ('262', 0.5303300858899106),
#  ('1085', 0.5303300858899106),
#  ('936', 0.5303300858899106),
#  ('1217', 0.5303300858899106),
#  ('1183', 0.5303300858899106),
#  ('1151', 0.5303300858899106),
#  ('384', 0.5303300858899106),
#  ('897', 0.5303300858899106),
#  ('925', 0.5303300858899106),
#  ('624', 0.5303300858899106),
#  ('846', 0.5303300858899106),
#  ('781', 0.5303300858899106),
#  ('383', 0.5303300858899106),
#  ('778', 0.5303300858899106),
#  ('780', 0.5303300858899106),
#  ('664', 0.5303300858899106),
#  ('610', 0.5303300858899106),
#  ('243', 0.5303300858899106),
#  ('274', 0.5303300858899106),
#  ('296', 0.5303300858899106),
#  ('369', 0.5303300858899106),
#  ('445', 0.5303300858899106),
#  ('1400', 0.5),
#  ('1284', 0.5),
#  ('1455', 0.5),
#  ('1401', 0.5),
#  ('1399', 0.5),
#  ('1410', 0.5),
#  ('1382', 0.5),
#  ('1386', 0.5),
#  ('1373', 0.5),
#  ('1387', 0.5),
#  ('1372', 0.5),
#  ('1328', 0.5),
#  ('1336', 0.5),
#  ('1340', 0.5),
#  ('1153', 0.5),
#  ('1161', 0.5),
#  ('1350', 0.5),
#  ('1351', 0.5),
#  ('1352', 0.5),
#  ('827', 0.5),
#  ('694', 0.5),
#  ('357', 0.5),
#  ('284', 0.5),
#  ('754', 0.5),
#  ('416', 0.5),
#  ('166', 0.5),
#  ('1246', 0.5),
#  ('836', 0.5),
#  ('568', 0.5),
#  ('1339', 0.5),
#  ('585', 0.5),
#  ('441', 0.5),
#  ('1275', 0.5),
#  ('676', 0.5),
#  ('406', 0.5),
#  ('305', 0.5),
#  ('215', 0.5),
#  ('533', 0.5),
#  ('1259', 0.5),
#  ('1265', 0.5),
#  ('1188', 0.5),
#  ('1232', 0.5),
#  ('1144', 0.5),
#  ('1290', 0.5),
#  ('1047', 0.5),
#  ('1252', 0.5),
#  ('1219', 0.5),
#  ('461', 0.5),
#  ('374', 0.4082482904638631),
#  ('485', 0.4082482904638631),
#  ('1228', 0.4008918628686366),
#  ('321', 0.3535533905932738),
#  ('1379', 0.35355339059327373),
#  ('1293', 0.35355339059327373),
#  ('1248', 0.35355339059327373),
#  ('1271', 0.35355339059327373),
#  ('363', 0.35355339059327373),
#  ('1002', 0.35355339059327373),
#  ('359', 0.35355339059327373),
#  ('298', 0.35355339059327373),
#  ('809', 0.35355339059327373),
#  ('548', 0.35355339059327373),
#  ('353', 0.35355339059327373),
#  ('1243', 0.35355339059327373),
#  ('951', 0.35355339059327373),
#  ('1241', 0.35355339059327373),
#  ('1028', 0.35355339059327373),
#  ('1158', 0.35355339059327373),
#  ('872', 0.35355339059327373),
#  ('1103', 0.35355339059327373),
#  ('709', 0.35355339059327373),
#  ('1128', 0.35355339059327373),
#  ('962', 0.35355339059327373),
#  ('575', 0.35355339059327373),
#  ('543', 0.35355339059327373),
#  ('701', 0.35355339059327373),
#  ('861', 0.35355339059327373),
#  ('859', 0.35355339059327373),
#  ('755', 0.35355339059327373),
#  ('574', 0.35355339059327373),
#  ('655', 0.35355339059327373),
#  ('570', 0.35355339059327373),
#  ('440', 0.35355339059327373),
#  ('635', 0.35355339059327373),
#  ('627', 0.35355339059327373),
#  ('612', 0.35355339059327373),
#  ('231', 0.35355339059327373),
#  ('233', 0.35355339059327373),
#  ('235', 0.35355339059327373),
#  ('236', 0.35355339059327373),
#  ('237', 0.35355339059327373),
#  ('240', 0.35355339059327373),
#  ('254', 0.35355339059327373),
#  ('258', 0.35355339059327373),
#  ('263', 0.35355339059327373),
#  ('303', 0.35355339059327373),
#  ('311', 0.35355339059327373),
#  ('320', 0.35355339059327373),
#  ('354', 0.35355339059327373),
#  ('361', 0.35355339059327373),
#  ('378', 0.35355339059327373),
#  ('417', 0.35355339059327373),
#  ('571', 0.35355339059327373),
#  ('628', 0.31622776601683794),
#  ('1478', 0.25),
#  ('1225', 0.25),
#  ('536', 0.25),
#  ('1245', 0.25),
#  ('1009', 0.25),
#  ('577', 0.25),
#  ('269', 0.25),
#  ('333', 0.25),
#  ('375', 0.25),
#  ('451', 0.25),
#  ('248', 0.17677669529663687),
#  ('251', 0.15811388300841897),
#  ('1471', 0.0),
#  ('355', 0.0),
#  ('1268', 0.0),
#  ('1355', 0.0),
#  ('916', 0.0),
#  ('1156', 0.0),
#  ('917', 0.0),
#  ('1247', 0.0),
#  ('456', 0.0),
#  ('1003', 0.0),
#  ('678', 0.0),
#  ('683', 0.0),
#  ('546', 0.0),
#  ('227', 0.0),
#  ('228', 0.0),
#  ('229', 0.0),
#  ('230', 0.0),
#  ('247', 0.0),
#  ('249', 0.0),
#  ('318', 0.0),
#  ('322', 0.0),
#  ('342', 0.0),
#  ('349', 0.0),
#  ('376', 0.0),
#  ('377', 0.0),
#  ('491', 0.0),
#  ('492', 0.0)]

# %% [markdown]
# The following results are the jaccard similarity scores of the bundles data and are in the form of a tuple (bundle id, jaccard similarity score) and the bundles in descending order and will be used to get the top k bundles to recommend to the users.

# %%
bundle_jaccard_sims
# Out:
# [('808', 0.7777777777777778),
#  ('663', 0.7777777777777778),
#  ('923', 0.75),
#  ('1206', 0.75),
#  ('398', 0.75),
#  ('948', 0.7),
#  ('396', 0.6666666666666666),
#  ('825', 0.6666666666666666),
#  ('929', 0.6666666666666666),
#  ('505', 0.6666666666666666),
#  ('364', 0.6666666666666666),
#  ('399', 0.6666666666666666),
#  ('482', 0.6666666666666666),
#  ('957', 0.6666666666666666),
#  ('804', 0.6666666666666666),
#  ('403', 0.6666666666666666),
#  ('934', 0.6666666666666666),
#  ('542', 0.6666666666666666),
#  ('331', 0.6666666666666666),
#  ('356', 0.6666666666666666),
#  ('450', 0.625),
#  ('1482', 0.625),
#  ('279', 0.625),
#  ('347', 0.625),
#  ('850', 0.625),
#  ('977', 0.625),
#  ('611', 0.625),
#  ('1250', 0.625),
#  ('434', 0.625),
#  ('990', 0.625),
#  ('1056', 0.625),
#  ('1054', 0.625),
#  ('1055', 0.625),
#  ('1040', 0.625),
#  ('949', 0.625),
#  ('920', 0.625),
#  ('854', 0.625),
#  ('728', 0.625),
#  ('665', 0.625),
#  ('153', 0.625),
#  ('260', 0.625),
#  ('350', 0.625),
#  ('433', 0.625),
#  ('476', 0.625),
#  ('484', 0.625),
#  ('514', 0.625),
#  ('803', 0.6),
#  ('813', 0.6),
#  ('1021', 0.6),
#  ('833', 0.6),
#  ('425', 0.6),
#  ('225', 0.6),
#  ('565', 0.6),
#  ('1440', 0.5555555555555556),
#  ('1441', 0.5555555555555556),
#  ('953', 0.5555555555555556),
#  ('501', 0.5555555555555556),
#  ('801', 0.5555555555555556),
#  ('1132', 0.5555555555555556),
#  ('1116', 0.5555555555555556),
#  ('1053', 0.5555555555555556),
#  ('824', 0.5555555555555556),
#  ('760', 0.5555555555555556),
#  ('569', 0.5555555555555556),
#  ('646', 0.5555555555555556),
#  ('746', 0.5555555555555556),
#  ('623', 0.5555555555555556),
#  ('616', 0.5555555555555556),
#  ('332', 0.5555555555555556),
#  ('339', 0.5555555555555556),
#  ('432', 0.5555555555555556),
#  ('436', 0.5555555555555556),
#  ('457', 0.5555555555555556),
#  ('460', 0.5555555555555556),
#  ('511', 0.5555555555555556),
#  ('580', 0.5454545454545454),
#  ('1404', 0.5),
#  ('1406', 0.5),
#  ('1407', 0.5),
#  ('1390', 0.5),
#  ('498', 0.5),
#  ('1378', 0.5),
#  ('567', 0.5),
#  ('982', 0.5),
#  ('622', 0.5),
#  ('653', 0.5),
#  ('1303', 0.5),
#  ('1190', 0.5),
#  ('1068', 0.5),
#  ('1289', 0.5),
#  ('1267', 0.5),
#  ('259', 0.5),
#  ('1216', 0.5),
#  ('650', 0.5),
#  ('1052', 0.5),
#  ('1130', 0.5),
#  ('1121', 0.5),
#  ('1110', 0.5),
#  ('437', 0.5),
#  ('1033', 0.5),
#  ('1034', 0.5),
#  ('480', 0.5),
#  ('955', 0.5),
#  ('802', 0.5),
#  ('395', 0.5),
#  ('855', 0.5),
#  ('852', 0.5),
#  ('805', 0.5),
#  ('687', 0.5),
#  ('532', 0.5),
#  ('798', 0.5),
#  ('779', 0.5),
#  ('429', 0.5),
#  ('459', 0.5),
#  ('696', 0.5),
#  ('680', 0.5),
#  ('474', 0.5),
#  ('634', 0.5),
#  ('534', 0.5),
#  ('239', 0.5),
#  ('268', 0.5),
#  ('292', 0.5),
#  ('293', 0.5),
#  ('302', 0.5),
#  ('308', 0.5),
#  ('334', 0.5),
#  ('336', 0.5),
#  ('358', 0.5),
#  ('385', 0.5),
#  ('424', 0.5),
#  ('426', 0.5),
#  ('428', 0.5),
#  ('454', 0.5),
#  ('469', 0.5),
#  ('472', 0.5),
#  ('588', 0.5),
#  ('1222', 0.4444444444444444),
#  ('704', 0.4444444444444444),
#  ('799', 0.4444444444444444),
#  ('1131', 0.4444444444444444),
#  ('362', 0.4444444444444444),
#  ('956', 0.4444444444444444),
#  ('810', 0.4444444444444444),
#  ('747', 0.4444444444444444),
#  ('725', 0.4444444444444444),
#  ('710', 0.4444444444444444),
#  ('631', 0.4444444444444444),
#  ('689', 0.4444444444444444),
#  ('301', 0.4444444444444444),
#  ('382', 0.4444444444444444),
#  ('447', 0.4444444444444444),
#  ('462', 0.4444444444444444),
#  ('467', 0.4444444444444444),
#  ('528', 0.4444444444444444),
#  ('1437', 0.4),
#  ('1005', 0.4),
#  ('1007', 0.4),
#  ('560', 0.4),
#  ('1143', 0.4),
#  ('984', 0.4),
#  ('1008', 0.4),
#  ('1460', 0.375),
#  ('317', 0.375),
#  ('658', 0.375),
#  ('1418', 0.375),
#  ('1282', 0.375),
#  ('1392', 0.375),
#  ('1332', 0.375),
#  ('667', 0.375),
#  ('1349', 0.375),
#  ('1295', 0.375),
#  ('972', 0.375),
#  ('473', 0.375),
#  ('1297', 0.375),
#  ('604', 0.375),
#  ('1333', 0.375),
#  ('903', 0.375),
#  ('1330', 0.375),
#  ('538', 0.375),
#  ('1114', 0.375),
#  ('1017', 0.375),
#  ('869', 0.375),
#  ('304', 0.375),
#  ('1191', 0.375),
#  ('1115', 0.375),
#  ('490', 0.375),
#  ('281', 0.375),
#  ('341', 0.375),
#  ('1150', 0.375),
#  ('1226', 0.375),
#  ('974', 0.375),
#  ('346', 0.375),
#  ('1266', 0.375),
#  ('1196', 0.375),
#  ('1291', 0.375),
#  ('1288', 0.375),
#  ('1105', 0.375),
#  ('763', 0.375),
#  ('1258', 0.375),
#  ('365', 0.375),
#  ('169', 0.375),
#  ('297', 0.375),
#  ('421', 0.375),
#  ('337', 0.375),
#  ('1071', 0.375),
#  ('893', 0.375),
#  ('651', 0.375),
#  ('1229', 0.375),
#  ('1182', 0.375),
#  ('516', 0.375),
#  ('1084', 0.375),
#  ('1104', 0.375),
#  ('344', 0.375),
#  ('1140', 0.375),
#  ('914', 0.375),
#  ('549', 0.375),
#  ('946', 0.375),
#  ('1041', 0.375),
#  ('963', 0.375),
#  ('983', 0.375),
#  ('961', 0.375),
#  ('668', 0.375),
#  ('823', 0.375),
#  ('954', 0.375),
#  ('871', 0.375),
#  ('520', 0.375),
#  ('868', 0.375),
#  ('510', 0.375),
#  ('380', 0.375),
#  ('697', 0.375),
#  ('647', 0.375),
#  ('464', 0.375),
#  ('770', 0.375),
#  ('772', 0.375),
#  ('773', 0.375),
#  ('766', 0.375),
#  ('767', 0.375),
#  ('768', 0.375),
#  ('690', 0.375),
#  ('712', 0.375),
#  ('736', 0.375),
#  ('721', 0.375),
#  ('656', 0.375),
#  ('670', 0.375),
#  ('649', 0.375),
#  ('496', 0.375),
#  ('633', 0.375),
#  ('17', 0.375),
#  ('137', 0.375),
#  ('145', 0.375),
#  ('157', 0.375),
#  ('244', 0.375),
#  ('250', 0.375),
#  ('256', 0.375),
#  ('266', 0.375),
#  ('272', 0.375),
#  ('285', 0.375),
#  ('300', 0.375),
#  ('307', 0.375),
#  ('309', 0.375),
#  ('326', 0.375),
#  ('327', 0.375),
#  ('328', 0.375),
#  ('329', 0.375),
#  ('335', 0.375),
#  ('338', 0.375),
#  ('340', 0.375),
#  ('345', 0.375),
#  ('414', 0.375),
#  ('420', 0.375),
#  ('439', 0.375),
#  ('442', 0.375),
#  ('448', 0.375),
#  ('449', 0.375),
#  ('487', 0.375),
#  ('488', 0.375),
#  ('503', 0.375),
#  ('535', 0.375),
#  ('540', 0.375),
#  ('547', 0.375),
#  ('578', 0.375),
#  ('586', 0.375),
#  ('594', 0.375),
#  ('1468', 0.36363636363636365),
#  ('1137', 0.36363636363636365),
#  ('413', 0.36363636363636365),
#  ('844', 0.36363636363636365),
#  ('845', 0.36363636363636365),
#  ('1477', 0.3333333333333333),
#  ('419', 0.3333333333333333),
#  ('1385', 0.3333333333333333),
#  ('1356', 0.3333333333333333),
#  ('1361', 0.3333333333333333),
#  ('1209', 0.3333333333333333),
#  ('1100', 0.3333333333333333),
#  ('507', 0.3333333333333333),
#  ('539', 0.3333333333333333),
#  ('614', 0.3333333333333333),
#  ('526', 0.3333333333333333),
#  ('262', 0.3333333333333333),
#  ('1085', 0.3333333333333333),
#  ('936', 0.3333333333333333),
#  ('1217', 0.3333333333333333),
#  ('1183', 0.3333333333333333),
#  ('1151', 0.3333333333333333),
#  ('384', 0.3333333333333333),
#  ('897', 0.3333333333333333),
#  ('925', 0.3333333333333333),
#  ('624', 0.3333333333333333),
#  ('846', 0.3333333333333333),
#  ('781', 0.3333333333333333),
#  ('383', 0.3333333333333333),
#  ('778', 0.3333333333333333),
#  ('780', 0.3333333333333333),
#  ('664', 0.3333333333333333),
#  ('610', 0.3333333333333333),
#  ('243', 0.3333333333333333),
#  ('274', 0.3333333333333333),
#  ('296', 0.3333333333333333),
#  ('369', 0.3333333333333333),
#  ('445', 0.3333333333333333),
#  ('1011', 0.3),
#  ('597', 0.3),
#  ('876', 0.3),
#  ('430', 0.3),
#  ('435', 0.3),
#  ('443', 0.3),
#  ('1204', 0.2727272727272727),
#  ('1207', 0.2727272727272727),
#  ('1194', 0.2727272727272727),
#  ('843', 0.2727272727272727),
#  ('512', 0.2727272727272727),
#  ('1400', 0.25),
#  ('1284', 0.25),
#  ('1455', 0.25),
#  ('1401', 0.25),
#  ('1399', 0.25),
#  ('1410', 0.25),
#  ('1382', 0.25),
#  ('1386', 0.25),
#  ('1373', 0.25),
#  ('1387', 0.25),
#  ('1372', 0.25),
#  ('1328', 0.25),
#  ('1336', 0.25),
#  ('1340', 0.25),
#  ('1153', 0.25),
#  ('1161', 0.25),
#  ('1350', 0.25),
#  ('1351', 0.25),
#  ('1352', 0.25),
#  ('827', 0.25),
#  ('694', 0.25),
#  ('357', 0.25),
#  ('284', 0.25),
#  ('754', 0.25),
#  ('416', 0.25),
#  ('166', 0.25),
#  ('1246', 0.25),
#  ('836', 0.25),
#  ('568', 0.25),
#  ('1339', 0.25),
#  ('585', 0.25),
#  ('441', 0.25),
#  ('1275', 0.25),
#  ('676', 0.25),
#  ('406', 0.25),
#  ('305', 0.25),
#  ('215', 0.25),
#  ('533', 0.25),
#  ('1259', 0.25),
#  ('1265', 0.25),
#  ('1188', 0.25),
#  ('1232', 0.25),
#  ('1144', 0.25),
#  ('1290', 0.25),
#  ('1047', 0.25),
#  ('1252', 0.25),
#  ('1219', 0.25),
#  ('461', 0.25),
#  ('1029', 0.25),
#  ('693', 0.25),
#  ('275', 0.25),
#  ('879', 0.25),
#  ('93', 0.25),
#  ('1233', 0.25),
#  ('995', 0.25),
#  ('1215', 0.25),
#  ('1228', 0.25),
#  ('1208', 0.25),
#  ('1189', 0.25),
#  ('552', 0.25),
#  ('941', 0.25),
#  ('1138', 0.25),
#  ('1107', 0.25),
#  ('865', 0.25),
#  ('853', 0.25),
#  ('884', 0.25),
#  ('926', 0.25),
#  ('944', 0.25),
#  ('877', 0.25),
#  ('832', 0.25),
#  ('837', 0.25),
#  ('700', 0.25),
#  ('851', 0.25),
#  ('759', 0.25),
#  ('730', 0.25),
#  ('757', 0.25),
#  ('782', 0.25),
#  ('695', 0.25),
#  ('751', 0.25),
#  ('749', 0.25),
#  ('752', 0.25),
#  ('753', 0.25),
#  ('727', 0.25),
#  ('771', 0.25),
#  ('774', 0.25),
#  ('775', 0.25),
#  ('776', 0.25),
#  ('761', 0.25),
#  ('762', 0.25),
#  ('764', 0.25),
#  ('765', 0.25),
#  ('769', 0.25),
#  ('379', 0.25),
#  ('724', 0.25),
#  ('682', 0.25),
#  ('729', 0.25),
#  ('394', 0.25),
#  ('718', 0.25),
#  ('572', 0.25),
#  ('608', 0.25),
#  ('662', 0.25),
#  ('125', 0.25),
#  ('139', 0.25),
#  ('232', 0.25),
#  ('234', 0.25),
#  ('241', 0.25),
#  ('245', 0.25),
#  ('255', 0.25),
#  ('257', 0.25),
#  ('261', 0.25),
#  ('264', 0.25),
#  ('265', 0.25),
#  ('267', 0.25),
#  ('270', 0.25),
#  ('273', 0.25),
#  ('278', 0.25),
#  ('306', 0.25),
#  ('313', 0.25),
#  ('316', 0.25),
#  ('366', 0.25),
#  ('367', 0.25),
#  ('381', 0.25),
#  ('391', 0.25),
#  ('408', 0.25),
#  ('409', 0.25),
#  ('438', 0.25),
#  ('471', 0.25),
#  ('495', 0.25),
#  ('497', 0.25),
#  ('519', 0.25),
#  ('579', 0.25),
#  ('581', 0.25),
#  ('582', 0.25),
#  ('584', 0.25),
#  ('1409', 0.2222222222222222),
#  ('531', 0.2222222222222222),
#  ('494', 0.2222222222222222),
#  ('1231', 0.2222222222222222),
#  ('913', 0.2222222222222222),
#  ('479', 0.2222222222222222),
#  ('1146', 0.2222222222222222),
#  ('1147', 0.2222222222222222),
#  ('1046', 0.2222222222222222),
#  ('1013', 0.2222222222222222),
#  ('1024', 0.2222222222222222),
#  ('509', 0.2222222222222222),
#  ('330', 0.2222222222222222),
#  ('708', 0.2222222222222222),
#  ('758', 0.2222222222222222),
#  ('280', 0.2222222222222222),
#  ('291', 0.2222222222222222),
#  ('312', 0.2222222222222222),
#  ('319', 0.2222222222222222),
#  ('374', 0.2222222222222222),
#  ('485', 0.2222222222222222),
#  ('321', 0.21428571428571427),
#  ('298', 0.2),
#  ('1028', 0.2),
#  ('655', 0.2),
#  ('570', 0.2),
#  ('440', 0.2),
#  ('378', 0.2),
#  ('628', 0.18181818181818182),
#  ('333', 0.14285714285714285),
#  ('1379', 0.125),
#  ('1293', 0.125),
#  ('1248', 0.125),
#  ('1271', 0.125),
#  ('363', 0.125),
#  ('1002', 0.125),
#  ('359', 0.125),
#  ('809', 0.125),
#  ('548', 0.125),
#  ('353', 0.125),
#  ('1243', 0.125),
#  ('951', 0.125),
#  ('1241', 0.125),
#  ('1158', 0.125),
#  ('872', 0.125),
#  ('1103', 0.125),
#  ('709', 0.125),
#  ('1128', 0.125),
#  ('962', 0.125),
#  ('575', 0.125),
#  ('543', 0.125),
#  ('701', 0.125),
#  ('861', 0.125),
#  ('859', 0.125),
#  ('755', 0.125),
#  ('574', 0.125),
#  ('635', 0.125),
#  ('627', 0.125),
#  ('612', 0.125),
#  ('231', 0.125),
#  ('233', 0.125),
#  ('235', 0.125),
#  ('236', 0.125),
#  ('237', 0.125),
#  ('240', 0.125),
#  ('254', 0.125),
#  ('258', 0.125),
#  ('263', 0.125),
#  ('303', 0.125),
#  ('311', 0.125),
#  ('320', 0.125),
#  ('354', 0.125),
#  ('361', 0.125),
#  ('417', 0.125),
#  ('571', 0.125),
#  ('1478', 0.1111111111111111),
#  ('1225', 0.1111111111111111),
#  ('536', 0.1111111111111111),
#  ('1245', 0.1111111111111111),
#  ('1009', 0.1111111111111111),
#  ('577', 0.1111111111111111),
#  ('269', 0.1111111111111111),
#  ('375', 0.1111111111111111),
#  ('451', 0.1111111111111111),
#  ('248', 0.09090909090909091),
#  ('251', 0.08333333333333333),
#  ('1471', 0.0),
#  ('355', 0.0),
#  ('1268', 0.0),
#  ('1355', 0.0),
#  ('916', 0.0),
#  ('1156', 0.0),
#  ('917', 0.0),
#  ('1247', 0.0),
#  ('456', 0.0),
#  ('1003', 0.0),
#  ('678', 0.0),
#  ('683', 0.0),
#  ('546', 0.0),
#  ('227', 0.0),
#  ('228', 0.0),
#  ('229', 0.0),
#  ('230', 0.0),
#  ('247', 0.0),
#  ('249', 0.0),
#  ('318', 0.0),
#  ('322', 0.0),
#  ('342', 0.0),
#  ('349', 0.0),
#  ('376', 0.0),
#  ('377', 0.0),
#  ('491', 0.0),
#  ('492', 0.0)]

# %%
# function takes the number of bundle recommendations to recommend to the active user
def get_bundle_recommendations(user_id, num_recommendations, sim, bundle_data=bundle_data):
    
    # list used to hold the top n bundles and recommend them to the user
    recommendations = []
    for id_ in sim[:num_recommendations]:
        for bundle in bundle_data:
            if bundle["bundle_id"]==id_[0]:
                recommendations.append(bundle)
                break
    
    return recommendations

# %%
cosine_recommendations = get_bundle_recommendations(users_items[0]["user_id"], 3, bundle_cosine_sims)

# %%
jaccard_recommendations = get_bundle_recommendations(users_items[0]["user_id"], 3, bundle_jaccard_sims)

# %% [markdown]
# The final results our our content-based recommender system is a list of bundles that were recommended to the active user based on the top played genres by the active user. Our algorithm only recommends the most similar bundles to the active user in order to maximize the user experience because recommending a bundle that user have no interest in will not be a very useful recommender's system. The following results are 3 bundles that were recommended using cosine similarity and jaccard similarity.

# %%
cosine_recommendations
# Out:
# [{'bundle_final_price': '$3.19',
#   'bundle_url': 'http://store.steampowered.com/bundle/808/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$28.79',
#   'bundle_name': 'Digital Homicide Super Bundle',
#   'bundle_id': '808',
#   'items': [{'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy',
#     'item_id': '314700',
#     'discounted_price': '$2.99',
#     'item_url': 'http://store.steampowered.com/app/314700',
#     'item_name': 'Forsaken Uprising'},
#    {'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy',
#     'item_id': '329950',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/329950',
#     'item_name': 'The Slaughtering Grounds'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '344750',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/344750',
#     'item_name': 'Deadly Profits'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '373110',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/373110',
#     'item_name': 'Temper Tantrum'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Strategy',
#     'item_id': '383030',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/383030',
#     'item_name': 'Medieval Mercs'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '388870',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/388870',
#     'item_name': 'Devils Share'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '392050',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/392050',
#     'item_name': 'Galactic Hitman'},
#    {'genre': 'Action, Casual, Indie, Simulation, Strategy',
#     'item_id': '392870',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/392870',
#     'item_name': 'Attrition: Nuclear Domination'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '407740',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/407740',
#     'item_name': 'Operation: Global Shield'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '407750',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/407750',
#     'item_name': 'Paranormal Psychosis'},
#    {'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Strategy',
#     'item_id': '407730',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/407730',
#     'item_name': 'Dungeons Of Kragmor'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '457930',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/457930',
#     'item_name': 'Starship: Nova Strike'},
#    {'genre': 'Action, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '457940',
#     'discounted_price': '$3.99',
#     'item_url': 'http://store.steampowered.com/app/457940',
#     'item_name': 'Krog Wars'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '473580',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473580',
#     'item_name': 'Wyatt Derp 2: Peacekeeper'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '473620',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473620',
#     'item_name': 'Winged Knights: Penetration'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '473630',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473630',
#     'item_name': 'Mini Attack Submarine'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '473640',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473640',
#     'item_name': 'Wyatt Derp'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '473650',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473650',
#     'item_name': 'Withering Kingdom: Arcane War'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '486340',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/486340',
#     'item_name': "Gnarltoof's Revenge"},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '491250',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/491250',
#     'item_name': 'The Decimation of Olarath'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '516230',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/516230',
#     'item_name': 'Withering Kingdom: Flurry Of Arrows'}],
#   'bundle_discount': '89%'},
#  {'bundle_final_price': '$109.22',
#   'bundle_url': 'http://store.steampowered.com/bundle/663/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$145.72',
#   'bundle_name': 'Meridian4 Publisher Bundle',
#   'bundle_id': '663',
#   'items': [{'genre': 'Indie, Casual',
#     'item_id': '2540',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/2540',
#     'item_name': 'RIP - Trilogy™'},
#    {'genre': 'Action, Indie',
#     'item_id': '19200',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/19200',
#     'item_name': 'Tank Universal'},
#    {'genre': 'Strategy, Indie, Action',
#     'item_id': '11240',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11240',
#     'item_name': 'Space Trader: Merchant Marine'},
#    {'genre': 'Action, Indie',
#     'item_id': '11340',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11340',
#     'item_name': 'Larva Mortus'},
#    {'genre': 'Casual, Indie',
#     'item_id': '11330',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11330',
#     'item_name': 'Obulis'},
#    {'genre': 'Indie',
#     'item_id': '11360',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11360',
#     'item_name': 'Chains'},
#    {'genre': 'Adventure',
#     'item_id': '11370',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11370',
#     'item_name': 'Nikopol: Secrets of the Immortals'},
#    {'genre': 'Action, Racing',
#     'item_id': '11390',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/11390',
#     'item_name': 'Crash Time 2'},
#    {'genre': 'Action, RPG',
#     'item_id': '46410',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/46410',
#     'item_name': 'Avencast: Rise of the Mage'},
#    {'genre': 'Action, Indie',
#     'item_id': '46520',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/46520',
#     'item_name': 'Wasteland Angel'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223313',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/223313',
#     'item_name': 'Frontline Tactics - Sniper'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223314',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/223314',
#     'item_name': 'Frontline Tactics - Close Quater Combat Soldier'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223315',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/223315',
#     'item_name': 'Frontline Tactics - Medic'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223318',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223318',
#     'item_name': 'Frontline Tactics - Desert Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223316',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223316',
#     'item_name': 'Frontline Tactics - Woodland Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223317',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223317',
#     'item_name': 'Frontline Tactics - Ninja Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223319',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223319',
#     'item_name': 'Frontline Tactics - Snow Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223320',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223320',
#     'item_name': 'Frontline Tactics - Tiger Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223321',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223321',
#     'item_name': 'Frontline Tactics - Golden Guns'},
#    {'genre': 'Adventure, Indie',
#     'item_id': '298140',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/298140',
#     'item_name': 'Rhiannon: Curse of the Four Branches'},
#    {'genre': 'Action, Indie, Strategy',
#     'item_id': '312960',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/312960',
#     'item_name': 'Starion Tactics'},
#    {'genre': 'Action, Indie',
#     'item_id': '315260',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/315260',
#     'item_name': 'Space Hack'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '321920',
#     'discounted_price': '$8.99',
#     'item_url': 'http://store.steampowered.com/app/321920',
#     'item_name': 'Schein'},
#    {'genre': 'Action, Casual, Indie, Strategy',
#     'item_id': '335080',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/335080',
#     'item_name': 'Biology Battle'},
#    {'genre': 'Action, Casual, Indie',
#     'item_id': '345130',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/345130',
#     'item_name': 'Dark Matter'},
#    {'genre': 'Adventure, Casual, Indie',
#     'item_id': '352520',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/352520',
#     'item_name': 'The Silent Age'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '355590',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/355590',
#     'item_name': 'Hektor - Official Soundtrack'},
#    {'genre': 'Action, Indie',
#     'item_id': '371510',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/371510',
#     'item_name': 'Gunnheim'}],
#   'bundle_discount': '25%'},
#  {'bundle_final_price': '$33.71',
#   'bundle_url': 'http://store.steampowered.com/bundle/923/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$44.96',
#   'bundle_name': 'The Black Watchmen - Occult Agent Edition',
#   'bundle_id': '923',
#   'items': [{'genre': 'Indie, Massively Multiplayer, RPG',
#     'item_id': '349220',
#     'discounted_price': '$14.99',
#     'item_url': 'http://store.steampowered.com/app/349220',
#     'item_name': 'The Black Watchmen'},
#    {'genre': 'Adventure, Casual, Indie, Massively Multiplayer, Strategy',
#     'item_id': '379750',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/379750',
#     'item_name': 'The Black Watchmen - Original Soundtrack'},
#    {'genre': 'Indie, Massively Multiplayer, RPG',
#     'item_id': '396810',
#     'discounted_price': '$14.99',
#     'item_url': 'http://store.steampowered.com/app/396810',
#     'item_name': 'The Black Watchmen - Season 2: Enduring Conflict'},
#    {'genre': 'Indie, Massively Multiplayer, RPG',
#     'item_id': '397370',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/397370',
#     'item_name': 'The Black Watchmen - Mother Russia'}],
#   'bundle_discount': '25%'}]

# %%
jaccard_recommendations
# Out:
# [{'bundle_final_price': '$3.19',
#   'bundle_url': 'http://store.steampowered.com/bundle/808/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$28.79',
#   'bundle_name': 'Digital Homicide Super Bundle',
#   'bundle_id': '808',
#   'items': [{'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy',
#     'item_id': '314700',
#     'discounted_price': '$2.99',
#     'item_url': 'http://store.steampowered.com/app/314700',
#     'item_name': 'Forsaken Uprising'},
#    {'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy',
#     'item_id': '329950',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/329950',
#     'item_name': 'The Slaughtering Grounds'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '344750',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/344750',
#     'item_name': 'Deadly Profits'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '373110',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/373110',
#     'item_name': 'Temper Tantrum'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Strategy',
#     'item_id': '383030',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/383030',
#     'item_name': 'Medieval Mercs'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '388870',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/388870',
#     'item_name': 'Devils Share'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '392050',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/392050',
#     'item_name': 'Galactic Hitman'},
#    {'genre': 'Action, Casual, Indie, Simulation, Strategy',
#     'item_id': '392870',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/392870',
#     'item_name': 'Attrition: Nuclear Domination'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '407740',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/407740',
#     'item_name': 'Operation: Global Shield'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '407750',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/407750',
#     'item_name': 'Paranormal Psychosis'},
#    {'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Strategy',
#     'item_id': '407730',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/407730',
#     'item_name': 'Dungeons Of Kragmor'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '457930',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/457930',
#     'item_name': 'Starship: Nova Strike'},
#    {'genre': 'Action, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '457940',
#     'discounted_price': '$3.99',
#     'item_url': 'http://store.steampowered.com/app/457940',
#     'item_name': 'Krog Wars'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '473580',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473580',
#     'item_name': 'Wyatt Derp 2: Peacekeeper'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '473620',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473620',
#     'item_name': 'Winged Knights: Penetration'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '473630',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473630',
#     'item_name': 'Mini Attack Submarine'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '473640',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473640',
#     'item_name': 'Wyatt Derp'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '473650',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/473650',
#     'item_name': 'Withering Kingdom: Arcane War'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '486340',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/486340',
#     'item_name': "Gnarltoof's Revenge"},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '491250',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/491250',
#     'item_name': 'The Decimation of Olarath'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '516230',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/516230',
#     'item_name': 'Withering Kingdom: Flurry Of Arrows'}],
#   'bundle_discount': '89%'},
#  {'bundle_final_price': '$109.22',
#   'bundle_url': 'http://store.steampowered.com/bundle/663/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$145.72',
#   'bundle_name': 'Meridian4 Publisher Bundle',
#   'bundle_id': '663',
#   'items': [{'genre': 'Indie, Casual',
#     'item_id': '2540',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/2540',
#     'item_name': 'RIP - Trilogy™'},
#    {'genre': 'Action, Indie',
#     'item_id': '19200',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/19200',
#     'item_name': 'Tank Universal'},
#    {'genre': 'Strategy, Indie, Action',
#     'item_id': '11240',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11240',
#     'item_name': 'Space Trader: Merchant Marine'},
#    {'genre': 'Action, Indie',
#     'item_id': '11340',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11340',
#     'item_name': 'Larva Mortus'},
#    {'genre': 'Casual, Indie',
#     'item_id': '11330',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11330',
#     'item_name': 'Obulis'},
#    {'genre': 'Indie',
#     'item_id': '11360',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11360',
#     'item_name': 'Chains'},
#    {'genre': 'Adventure',
#     'item_id': '11370',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/11370',
#     'item_name': 'Nikopol: Secrets of the Immortals'},
#    {'genre': 'Action, Racing',
#     'item_id': '11390',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/11390',
#     'item_name': 'Crash Time 2'},
#    {'genre': 'Action, RPG',
#     'item_id': '46410',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/46410',
#     'item_name': 'Avencast: Rise of the Mage'},
#    {'genre': 'Action, Indie',
#     'item_id': '46520',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/46520',
#     'item_name': 'Wasteland Angel'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223313',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/223313',
#     'item_name': 'Frontline Tactics - Sniper'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223314',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/223314',
#     'item_name': 'Frontline Tactics - Close Quater Combat Soldier'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223315',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/223315',
#     'item_name': 'Frontline Tactics - Medic'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223318',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223318',
#     'item_name': 'Frontline Tactics - Desert Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223316',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223316',
#     'item_name': 'Frontline Tactics - Woodland Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223317',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223317',
#     'item_name': 'Frontline Tactics - Ninja Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223319',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223319',
#     'item_name': 'Frontline Tactics - Snow Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223320',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223320',
#     'item_name': 'Frontline Tactics - Tiger Camouflage'},
#    {'genre': 'Action, Free to Play, Strategy',
#     'item_id': '223321',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/223321',
#     'item_name': 'Frontline Tactics - Golden Guns'},
#    {'genre': 'Adventure, Indie',
#     'item_id': '298140',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/298140',
#     'item_name': 'Rhiannon: Curse of the Four Branches'},
#    {'genre': 'Action, Indie, Strategy',
#     'item_id': '312960',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/312960',
#     'item_name': 'Starion Tactics'},
#    {'genre': 'Action, Indie',
#     'item_id': '315260',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/315260',
#     'item_name': 'Space Hack'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '321920',
#     'discounted_price': '$8.99',
#     'item_url': 'http://store.steampowered.com/app/321920',
#     'item_name': 'Schein'},
#    {'genre': 'Action, Casual, Indie, Strategy',
#     'item_id': '335080',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/335080',
#     'item_name': 'Biology Battle'},
#    {'genre': 'Action, Casual, Indie',
#     'item_id': '345130',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/345130',
#     'item_name': 'Dark Matter'},
#    {'genre': 'Adventure, Casual, Indie',
#     'item_id': '352520',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/352520',
#     'item_name': 'The Silent Age'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '355590',
#     'discounted_price': '$5.99',
#     'item_url': 'http://store.steampowered.com/app/355590',
#     'item_name': 'Hektor - Official Soundtrack'},
#    {'genre': 'Action, Indie',
#     'item_id': '371510',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/371510',
#     'item_name': 'Gunnheim'}],
#   'bundle_discount': '25%'},
#  {'bundle_final_price': '$33.71',
#   'bundle_url': 'http://store.steampowered.com/bundle/923/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$44.96',
#   'bundle_name': 'The Black Watchmen - Occult Agent Edition',
#   'bundle_id': '923',
#   'items': [{'genre': 'Indie, Massively Multiplayer, RPG',
#     'item_id': '349220',
#     'discounted_price': '$14.99',
#     'item_url': 'http://store.steampowered.com/app/349220',
#     'item_name': 'The Black Watchmen'},
#    {'genre': 'Adventure, Casual, Indie, Massively Multiplayer, Strategy',
#     'item_id': '379750',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/379750',
#     'item_name': 'The Black Watchmen - Original Soundtrack'},
#    {'genre': 'Indie, Massively Multiplayer, RPG',
#     'item_id': '396810',
#     'discounted_price': '$14.99',
#     'item_url': 'http://store.steampowered.com/app/396810',
#     'item_name': 'The Black Watchmen - Season 2: Enduring Conflict'},
#    {'genre': 'Indie, Massively Multiplayer, RPG',
#     'item_id': '397370',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/397370',
#     'item_name': 'The Black Watchmen - Mother Russia'}],
#   'bundle_discount': '25%'}]

# %% [markdown]
# Now I will evaluate the recommended bundles generated by cosine similarity and jaccard similarity and see how similarl the top bundles are to the top played genres of the active user. As you can see from the outputs above, the bundles generated by cosine similarity and jaccard similarity are the same but cosine similarity generated a higher similarity score than jaccard similarity.

# %% [markdown]
# # Use Case #2: Bundle generation and recommendation for a group of users

# %% [markdown]
# The second use case that we'll be covering is recommending personalized bundles to a group of users. On the Steam platform, there are community groups where users are able to interact and share their progress on a game and we wanted to implement a recommender's system that can effectively recommend personalized bundles for the group of users to enjoy and play together.

# %% [markdown]
# # Group Generation

# %% [markdown]
# What we are doing here is creating a community of users that are most similar (users that show interest in similar genres of games) to the active user. The purpose of generating a group of users that are most similar to one another is to ensure that the personalized bundle that we will be creating will soothe and appease all users in the community. This approach is better than random selection of users because not everyone will like the same types of games.

# %%
# function used to generate a group of users that are most similar (users that have played similar genres of games) to the active user
# function takes two parameters:
# user_id: the id of the active user
# num_of_users: the total number of users to form a community for
def group_generation(user_data, num_of_users):
            
    user_df = json_normalize(user_data, "items", ["user_id", "steam_id", "user_url"])
    user_df = user_df[user_df["playtime_forever"] > 60]
    
    # gets the list of top genres played by the active user
    genres = get_all_genres_by_user(user_df)
    top_rated_genres = parse_genres(genres)

    # used to store the most similar users to the active user
    sim = {}
    sim[active_user_data["user_id"]] = 1
    counter = 1
    
    # loop through all users and find most similar users
    for user in users_items:
        if user["user_id"]!=active_user_data["user_id"]:
            u_df = json_normalize(user, "items", ["user_id", "steam_id", "user_url"])
            g = get_all_genres_by_user(u_df)
            parsed_genres = parse_genres(g)
            
            cos, magnitude = cosine_sim(top_rated_genres, parsed_genres)
            
            if magnitude==0:
                continue
                
            if cos >= 0.85:
                counter += 1
                sim[user["user_id"]] = cos
                
            if counter == num_of_users:
                break
                    
    return sorted(sim, key=operator.itemgetter(1), reverse=True)

# %%
users_group = group_generation(active_user_data, 100)

# %% [markdown]
# The results of group generation based on the active user can be seen below. The user id's of similar users are stored in a list that will be used later for bundle generation and recommendation.

# %%
users_group
# Out:
# ['dxzone12359',
#  'Owlybastard',
#  'jukeboxplays',
#  'btrab1',
#  'itsfilfyd',
#  'mtmoss',
#  'GravityI',
#  'pr3vious',
#  'SoenBR',
#  'Umegadem',
#  'Imvoo',
#  'plokinub',
#  'BlackCockTetrisBlock',
#  'alifyandra',
#  'akaBryce',
#  'Skr0fsnews',
#  'Nikita50111',
#  'the_bassist',
#  'TheRedArrowGaming',
#  'thesiminerd',
#  'Ffourfive',
#  'Berserklejerker',
#  'PenguinAKandreas',
#  'ZeroMark2',
#  'keamy911',
#  'zerrun',
#  'Denroxyou',
#  'BearVoSir',
#  'vckx2',
#  'FancySomething',
#  'samcab',
#  'Salttyy',
#  'Nadarrus',
#  'farquadspenis',
#  'CarmineZeppelin',
#  'JasonAtHome',
#  'Raeikar',
#  'captainploot',
#  'Haydenlf',
#  '76561198074419128',
#  '76561198068070754',
#  '76561198037000282',
#  '76561198096153310',
#  '76561198079366874',
#  '76561198000595834',
#  '76561198079228209',
#  '76561198028545074',
#  '76561198076783639',
#  '76561198062411680',
#  '76561198089399646',
#  '76561198066636734',
#  '76561198045590598',
#  '76561198039668365',
#  '76561198097453305',
#  '76561198082180794',
#  '76561198071027874',
#  '76561198095847205',
#  '76561198070894525',
#  '76561198022505404',
#  '76561198032126834',
#  '76561198055516353',
#  '76561198059737487',
#  '76561198085975327',
#  '76561198171771974',
#  '76561198105153545',
#  '76561198043026878',
#  '76561198096632715',
#  '76561198036742977',
#  '76561198056803716',
#  '76561198115492671',
#  '76561198005303239',
#  '76561198043108838',
#  '76561198028390064',
#  '76561198076480636',
#  '76561198062630453',
#  '76561198011214586',
#  '76561198076371615',
#  '76561198087566671',
#  '76561198025690763',
#  '76561198063588999',
#  '76561198041963382',
#  '76561198191146478',
#  '76561198004404511',
#  '76561198078738103',
#  '76561198096791483',
#  '76561198092735015',
#  '76561198059297514',
#  '76561198021622222',
#  '76561198111408860',
#  '76561198083140614',
#  '76561198068311909',
#  '76561198078054733',
#  '76561197970137892',
#  '76561198093816042',
#  '76561198067645123',
#  '76561198060031056',
#  '76561198063714964',
#  '76561197986717785',
#  '76561198058247995',
#  '13371337133713337']

# %% [markdown]
# # Bundle Generation and Recommedation

# %% [markdown]
# Generating a community of users was the first part of this use case, generating a personalized bundle and recommending the group of users this bundle is the second part. How bundle generation works is because we are working with a group of users as opposed to a single user, we will only focus on the online multiplayer games in the steam games dataset for our bundle generation. This will allow users in the community to play and enjoy the games together to their fit.

# %%
# function used to filter out only the multiplayer games in the steam games dataset
# function parameters:
# steam_games: steam games dataset
def get_multiplayer_games(steam_games):
    games = steam_games.copy()
    
    # loop through each game in the steam games dataset to find only the online multiplayer games 
    for i, row in games.iterrows():
        flag = False
        if type(row["specs"]) != list:
            games.drop([i], inplace=True)
            continue
            
        for spec in row["specs"]:
            if spec=="Online Multi-Player":
                flag = True
                break
                
        if flag==False:
            games.drop([i], inplace=True)
            
    games.reset_index(inplace=True)
    
    # used to fill in any empty values for discount price and price b/c free to play items are string values
    games["discount_price"].fillna(0, inplace=True)
    games["price"].fillna(0, inplace=True)
    
    return games

# %%
multiplayer_games = get_multiplayer_games(steam_games_df)

# %% [markdown]
# This is done to get the top genres from the users group which will be used to generate a personalized bundle for the users group to enjoy.

# %%
# function used to get the top genres from the users group
# function parameters:
# users_group: the user group generated
def get_top_genres_from_users_group(users_group):
    all_genres = {}
    
    for user in users_group:
        user_data = {}
        for u in users_items:
            if u["user_id"]==user:
                user_data = u
                break
            
        user_df = json_normalize(user_data, "items", ["user_id", "steam_id", "user_url"])
    
        genres = get_all_genres_by_user(user_df)
    
        for genre in genres:
            if genre[0] not in all_genres:
                all_genres[genre[0]] = genre[1]
            else:
                all_genres[genre[0]] += genre[1]
          
    all_genres = sorted(all_genres.items(), key=operator.itemgetter(1), reverse=True)
    
    return parse_genres(all_genres)

# %%
top_users_group_genres = get_top_genres_from_users_group(users_group)

# %% [markdown]
# As you can see here are the top genres from the users group, which is not much different than the top genres of the active user. This is expected because only similar users were picked to form the users group.

# %%
top_users_group_genres
# Out:
# ['Action',
#  'Indie',
#  'Adventure',
#  'RPG',
#  'Free to Play',
#  'Strategy',
#  'Massively Multiplayer',
#  'Simulation',
#  'Casual',
#  'Early Access',
#  'Sports',
#  'Racing']

# %%
# function is used to get top n games from the multiplayer's dataframe
# function parameters are:
# games: multiplayer dataframe
# users_group: the group of users generated
# top_genres: the top genres from the users group
# num_of_games: the number of games to select for bundle generation
def get_most_similar_games(games, users_group, top_genres, num_of_games):
    sim = {}
    for i, row in games.iterrows():
        game_genres = row["genres"]
        
        cos, magnitude = cosine_sim(top_genres, game_genres)
        
        if magnitude==0:
            continue
                
        sim[row["id"]] = cos
    
    sim = sorted(sim.items(), key=operator.itemgetter(1), reverse=True)
    
    # only return the given number of games which will be used to form the bundle
    games_list = []
    for i in sim[:num_of_games]:
        games_list.append(i[0])
        
    return games_list

# %%
list_of_games = get_most_similar_games(multiplayer_games, users_group, top_users_group_genres, 10)

# %% [markdown]
# Here are the list of games that were selected based on the top genres from the users group. These games will be used to generate a personalized bundle based off of genres of games every user in the group has played or have interest in.

# %%
list_of_games
# Out:
# ['622470',
#  '515710',
#  '638180',
#  '462440',
#  '461430',
#  '333340',
#  '413120',
#  '393930',
#  '496510',
#  '563410']

# %% [markdown]
# Now using the list of multiplayer games generated above, we will create a personalized bundle out of those games and recommend that to the group of users.

# %%
# function used to generate a personalized bundle based off of games selected
def bundle_generation(games):
    
    # object used to store bundle data
    bundle = {}
    bundle["bundle_name"] = "Made just for you"
    bundle["bundle_id"] = "MADE FOR YOU"
    bundle["items"] = []
    discounted_total = 0
    total_price = 0
    
    # for each game selected, generate item data for it
    for id_ in games:
        game = multiplayer_games[multiplayer_games["id"]==id_]
        
        item_info = {}
        item_info["item_id"] = id_
        item_info["genre"] = ', '.join(map(str, game["genres"].values[0]))
        item_info["name"] = game["title"].values[0]
        
        if type(game["price"].values[0]) != str:
            total_price += game["price"].values[0]
        else:
            total_price += 0
        
        discounted_total += game["discount_price"].values[0]
        
        bundle["items"].append(item_info)
    
    # the final price of the bundle will be prices of all the games minus the discounts steam has provided
    bundle["bundle_final_price"] = total_price - discounted_total
    
    return bundle

# %%
personalized_bundle = bundle_generation(list_of_games)

# %% [markdown]
# Here is the personalized bundle generated for the group of users that were selected. These games were hand picked and the bundle was designed based on the genres of games users in the group has played the most. This personalized bundle will be used to evaluate against all the pre-existing bundles in the bundles dataset to see how well our personalized bundle perform against the existing bundles.

# %%
personalized_bundle
# Out:
# {'bundle_name': 'Made just for you',
#  'bundle_id': 'MADE FOR YOU',
#  'items': [{'item_id': '622470',
#    'genre': 'Action, Adventure, Free to Play, Indie, Massively Multiplayer, Racing, RPG, Strategy, Early Access',
#    'name': 'Road Dogs'},
#   {'item_id': '515710',
#    'genre': 'Action, Adventure, Casual, Free to Play, Indie, Massively Multiplayer, RPG, Simulation',
#    'name': 'Creativerse - Pro'},
#   {'item_id': '638180',
#    'genre': 'Action, Adventure, Casual, Free to Play, Indie, Massively Multiplayer, RPG, Simulation',
#    'name': 'Creativerse - Welcome Bundle'},
#   {'item_id': '462440',
#    'genre': 'Action, Adventure, Indie, Massively Multiplayer, RPG, Simulation, Strategy, Early Access',
#    'name': 'ROKH'},
#   {'item_id': '461430',
#    'genre': 'Action, Casual, Indie, Racing, RPG, Simulation, Strategy, Early Access',
#    'name': 'EmergeNYC'},
#   {'item_id': '333340',
#    'genre': 'Action, Adventure, Casual, Indie, Racing, RPG, Simulation, Early Access',
#    'name': 'Star Rangers™ XE'},
#   {'item_id': '413120',
#    'genre': 'Action, Casual, Indie, Massively Multiplayer, Simulation, Sports, Strategy',
#    'name': 'Tactics Forever'},
#   {'item_id': '393930',
#    'genre': 'Action, Casual, Free to Play, Indie, RPG, Sports, Early Access',
#    'name': 'RoShamBo'},
#   {'item_id': '496510',
#    'genre': 'Action, Adventure, Indie, RPG, Simulation, Strategy, Early Access',
#    'name': 'M.EXE'},
#   {'item_id': '563410',
#    'genre': 'Action, Casual, Indie, RPG, Sports, Strategy, Early Access',
#    'name': 'Necroball'}],
#  'bundle_final_price': 116.92999999999999}

# %%
genres_from_personalized_bundle = extract_genres_data_from_bundles(json_normalize(personalized_bundle, "items", ["bundle_final_price", "bundle_name", "bundle_id"]))

# %% [markdown]
# These are the top rated genres from the personalized bundle that will be used to evaluate how well the games in the bundle perform against the most played genres from the users group.

# %%
genres_from_personalized_bundle
# Out:
# {'MADE FOR YOU': ['Action',
#   'Adventure',
#   'Free to Play',
#   'Indie',
#   'Massively Multiplayer',
#   'Racing',
#   'RPG',
#   'Strategy',
#   'Early Access',
#   'Casual',
#   'Simulation',
#   'Sports']}

# %% [markdown]
# Now we will perform evaluation on the personalized bundle to see how the newly personalized bundle holds up against the pre-existing bundles. The results of this function will be the cosine similarity scores and jaccard similarity scores between top genres of the users group and all bundles including the personalized bundle in descending order because we want to visualize how well the new bundle performed.

# %%
# function is used to evaluate the personalized bundle against all pre-existing bundles
def evaluate_generated_bundle(users_group, all_bundles_genres_data, bundle_sim):
    cos_sim = {}
    jac_sim = {}
    for user in users_group:
        user_data = {}
        
        for u in users_items:
            if u["user_id"]==user:
                user_data = u
                break

        user_df = json_normalize(user_data, "items", ["user_id", "steam_id", "user_url"])
        user_df = user_df[user_df["playtime_forever"] > 100]

        genres = get_all_genres_by_user(user_df)
        top_rated_genres = parse_genres(genres)
        
        # calculate the summation of cosine and jaccard similarties between all users in the users group
        # this will be used to evaluate how well the personalized bundle compares against all other bundles in the bundles data
        # the higher the personalized bundle is in the output the better it performs
        for id_ in list(all_bundles_genres_data.keys()):
            if id_ not in cos_sim:
                cos_sim[id_] = 0
            if id_ not in jac_sim:
                jac_sim[id_] = 0
                
            bundle_genres = all_bundles_genres_data[id_]

            cos,_ = cosine_sim(top_rated_genres, bundle_genres)
            jac = jaccard_sim(top_rated_genres, bundle_genres)

            cos_sim[id_] += cos
            jac_sim[id_] += jac
            
        for id_ in list(bundle_sim.keys()):
            if id_ not in cos_sim:
                cos_sim[id_] = 0
            if id_ not in jac_sim:
                jac_sim[id_] = 0
                
            bundle_genres = bundle_sim[id_]

            cos,_ = cosine_sim(top_rated_genres, bundle_genres)
            jac = jaccard_sim(top_rated_genres, bundle_genres)
            
            cos_sim[id_] += cos
            jac_sim[id_] += jac
            
    return sorted(cos_sim.items(), key=operator.itemgetter(1), reverse=True), sorted(jac_sim.items(), key=operator.itemgetter(1), reverse=True)

# %%
bundle_cosine_similarities, bundle_jaccard_similarities = evaluate_generated_bundle(users_group, all_bundles_genres_data, genres_from_personalized_bundle)

# %%
bundle_cosine_similarities
# Out:
# [('948', 77.58215208188692),
#  ('646', 76.97517706632573),
#  ('339', 76.97517706632573),
#  ('808', 76.8911678627958),
#  ('396', 76.29855753387635),
#  ('505', 76.29855753387635),
#  ('364', 76.29855753387635),
#  ('399', 76.29855753387635),
#  ('482', 76.29855753387635),
#  ('957', 76.29855753387635),
#  ('804', 76.29855753387635),
#  ('403', 76.29855753387635),
#  ('542', 76.29855753387635),
#  ('356', 76.29855753387635),
#  ('347', 75.11183040803196),
#  ('990', 75.11183040803196),
#  ('728', 75.11183040803196),
#  ('260', 75.11183040803196),
#  ('663', 74.37953610576872),
#  ('1206', 74.00409052357786),
#  ('398', 74.00409052357786),
#  ('824', 73.20596722803474),
#  ('623', 73.20596722803474),
#  ('653', 72.70270795739872),
#  ('1068', 72.70270795739872),
#  ('1130', 72.70270795739872),
#  ('474', 72.70270795739872),
#  ('302', 72.70270795739872),
#  ('336', 72.70270795739872),
#  ('385', 72.70270795739872),
#  ('428', 72.70270795739872),
#  ('833', 72.24818502583547),
#  ('565', 72.24818502583547),
#  ('1409', 16.73446275946275),
#  ('851', 16.57943722943722),
#  ('251', 16.411541236541225),
#  ('536', 15.708874458874456),
#  ('577', 15.708874458874456),
#  ('269', 15.708874458874456),
#  ('451', 15.708874458874456),
#  ('363', 15.374675324675316),
#  ('359', 15.374675324675316),
#  ('1241', 15.374675324675316),
#  ('627', 15.374675324675316),
#  ('333', 14.98543066410712),
#  ('1225', 14.958008658008643),
#  ('375', 14.34166666666665),
#  ('1009', 14.247222222222208),
#  ('1379', 13.674675324675318),
#  ('1271', 13.674675324675318),
#  ('1002', 13.674675324675318),
#  ('1103', 13.674675324675318),
#  ('709', 13.674675324675318),
#  ('1128', 13.674675324675318),
#  ('263', 13.674675324675318),
#  ('361', 13.674675324675318),
#  ('417', 13.674675324675318),
#  ('962', 12.848484848484842),
#  ('859', 12.848484848484842),
#  ('635', 12.848484848484842),
#  ('1478', 11.802453102453095),
#  ('319', 11.313431013431003),
#  ('548', 8.724675324675328),
#  ('353', 8.724675324675328),
#  ('951', 8.724675324675328),
#  ('872', 8.724675324675328),
#  ('575', 8.724675324675328),
#  ('543', 8.724675324675328),
#  ('574', 8.724675324675328),
#  ('303', 8.724675324675328),
#  ('311', 8.724675324675328),
#  ('354', 8.724675324675328),
#  ('1471', 7.77705627705628),
#  ('1247', 7.77705627705628),
#  ('1268', 7.038095238095235),
#  ('355', 6.544827394827391),
#  ('1355', 6.544827394827391),
#  ('1156', 6.544827394827391),
#  ('683', 6.544827394827391),
#  ('247', 6.544827394827391),
#  ('349', 6.544827394827391),
#  ('861', 5.164718614718615),
#  ('571', 5.164718614718615),
#  ('249', 0.5277777777777778),
#  ('377', 0.25),
#  ('456', 0.08333333333333333),
#  ('322', 0.0625),
#  ('916', 0.0),
#  ('917', 0.0),
#  ('1003', 0.0),
#  ('678', 0.0),
#  ('546', 0.0),
#  ('227', 0.0),
#  ('228', 0.0),
#  ('229', 0.0),
#  ('230', 0.0),
#  ('318', 0.0),
#  ('342', 0.0),
#  ('376', 0.0),
#  ('491', 0.0),
#  ('492', 0.0)]

# %% [markdown]
# The results show that the personalized bundle performed in the top percentile of all the bundles in the bundles dataset using cosine and jaccard similarities. Both similarity metrics generated the same output and specified that our personalized bundle performed better than most bundles in the bundles data. This means that our personalized bundle caters to the users group better than most bundles in the bundles data. It is no surprise that our bundle performs well with the users group because this was generated using the top games the each user in the users group has played.

# %%
print("Using cosine similarity, our personalized bundle sits in the top {}th percentile of all bundles data.".format(int(100-(([x[0] for x in bundle_cosine_similarities].index("MADE FOR YOU")+1)/len(bundle_cosine_similarities)*100))))
# Out:
# Using cosine similarity, our personalized bundle sits in the top 94th percentile of all bundles data.

# %%
print("Using jaccard similarity, our personalized bundle sits in the top {}th percentile of all bundles data.".format(int(100-(([x[0] for x in bundle_cosine_similarities].index("MADE FOR YOU")+1)/len(bundle_jaccard_similarities)*100))))
# Out:
# Using jaccard similarity, our personalized bundle sits in the top 94th percentile of all bundles data.

# %% [markdown]
# # Use Case #3: Recommending specfic games to the active user

# %% [markdown]
# The third use case of our recommender's system is recommending specific games to the active user. This is done by using cosine and jaccard similarities to find similar games to the one user has selected. For instance, a user clicks on a specific game on the Steam platform, he/she are able to view similar games to the one he/she has selected.

# %% [markdown]
# Here we will be generating top game recommendations to the active user based on the top genres played by the active user. We will take two approaches when generating the game recommendations using cosine similarity and jaccard similarity. The results are recommendations using cosine and jaccard similarities which will be used to evaluate later.

# %%
# function is used to generate game recommendations based on top user's genres
def get_game_recommendations(num_recommendations):
    
    np.random.shuffle(active_user_data["items"])
    
    # user selects a random game from his/her dashboard
    selected_game = None
    for game in active_user_data["items"]:
        if steam_games_df[steam_games_df["id"]==game["item_id"]].index.any()==True:
            selected_game = steam_games_df[steam_games_df["id"]==game["item_id"]]
            break
       
    # calculate cosine and jaccard similarity on all games
    cos_sim = {}
    jac_sim = {}
    for i, row in steam_games_df.iterrows():
        game_genres = row["genres"]
        
        cos,_ = cosine_sim(selected_game["genres"].values[0], game_genres)
        jac = jaccard_sim(selected_game["genres"].values[0], game_genres)
        
        cos_sim[row["id"]] = cos
        jac_sim[row["id"]] = jac

    sorted_cos = sorted(cos_sim.items(), key=operator.itemgetter(1), reverse=True)
    sorted_jac = sorted(jac_sim.items(), key=operator.itemgetter(1), reverse=True)
    
    # used to store the top game recommendations for a specific game
    cosine_recommendations = []
    jaccard_recommendations = []
    
    # get the top game recommendations from cosine similarity output
    for i in sorted_cos[:num_recommendations]:
        cosine_recommendations.append(steam_games_df[steam_games_df["id"]==i[0]]["title"].values[0])
        
    # get the top game recommendations from jaccard similarity output
    for i in sorted_jac[:num_recommendations]:
        jaccard_recommendations.append(steam_games_df[steam_games_df["id"]==i[0]]["title"].values[0])
        
    return selected_game, cosine_recommendations, jaccard_recommendations

# %%
user_selected_game, cosine_game_recommendations, jaccard_game_recommendations = get_game_recommendations(3)

# %% [markdown]
# Here is the game selected by the user on his/her dashboard and below are the game recommendations generated by cosine and jaccard similarities.

# %%
user_selected_game
# Out:
#       publisher                  genres           title  \
# 27397        2K  [Action, Free to Play]  Evolve Stage 2
#
#                                                      url release_date  \
# 27397  http://store.steampowered.com/app/273350/Evolv...   2015-02-10
#
#        discount_price                                        reviews_url  \
# 27397             NaN  http://steamcommunity.com/app/273350/reviews/?...
#
#                                                    specs         price  \
# 27397  [Single-player, Multi-player, Co-op, Full cont...  Free to Play
#
#        early_access      id            developer sentiment
# 27397         False  273350  Turtle Rock Studios     Mixed

# %%
cosine_game_recommendations
# Out:
# ['A.V.A. Alliance of Valiant Arms™', 'Tribes: Ascend', 'Soldier Front 2']

# %%
jaccard_game_recommendations
# Out:
# ['A.V.A. Alliance of Valiant Arms™', 'Tribes: Ascend', 'Soldier Front 2']

# %% [markdown]
# As the results show, using Jaccard and Cosine similarity on the active user's genres and trying to find similar games to that user based on genres of other games is the better approach. The recommendations also show that for a selected game, the same output was generated by Jaccard and Cosine indicating accurate similarity.

# %% [markdown]
# Below shows the genres of the recommended games generated by the recommender system and as you can see the genres of the games are the same as the user selected game which proves the system were generate proper, accurate recommendations and worked to our expectations.

# %%
for game in cosine_game_recommendations:
    print("The game genres of {} are {}.".format(game, steam_games_df[steam_games_df["title"]==game]["genres"].values[0]))
# Out:
# The game genres of A.V.A. Alliance of Valiant Arms™ are ['Action', 'Free to Play'].
# The game genres of Tribes: Ascend are ['Action', 'Free to Play'].
# The game genres of Soldier Front 2 are ['Action', 'Free to Play'].
