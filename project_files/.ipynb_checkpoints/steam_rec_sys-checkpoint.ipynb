# %%
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import operator
import math
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/stevenlouie/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Process data files

# %%
def eval_file(file):
    f = open(file, "r", encoding="utf-8")
    lst = []
    for line in f:
        obj = eval(line)
        lst.append(obj)
    json.dumps(lst)
    return lst

# %%
bundle_data = eval_file("../data/bundle_data.json")
users_items = eval_file("../data/australian_users_items.json")
steam_games = eval_file("../data/steam_games.json")

# %%
bundle_df = json_normalize(bundle_data, "items", ["bundle_final_price", "bundle_url", "bundle_price", "bundle_name", "bundle_id"])
steam_games_df = pd.DataFrame(data=steam_games)

# %% [markdown]
# # Data Preprocessing

# %%
def clean_bundle_data():    
    clean_bundle_df = bundle_df[bundle_df["genre"]!=""]
    return clean_bundle_df

# %%
def clean_games_data():
    steam_games_df.drop(labels=["app_name", "tags", "metascore"], axis=1, inplace=True)
    steam_games_df.dropna(subset=["title", "genres"], inplace=True)

# %%
def remove_idle_users():
    for i in users_items:
        if i["items_count"]==0:
            users_items.remove(i)

# %%
def perform_data_preprocessing():
    clean_games_data()
    remove_idle_users()

# %%
def filter_by_playtime(user_id, playtime):
    user_data = {}
    
    for user in users_items:
        if user["user_id"]==user_id:
            user_data = user
            break
    
    filtered_df = json_normalize(user_data, "items", ["user_id", "steam_id", "user_url"])
    filtered_df = filtered_df[filtered_df["playtime_forever"] > playtime]
    
    return filtered_df

# %%
def extract_genres_data_from_bundles(): 
    
    clean_bundle_df = clean_bundle_data()
    
    filter_genre_from_bundle = {}
    for id_ in clean_bundle_df["bundle_id"].unique():
        genres_list = []
#         words = ""
        for genres in clean_bundle_df[clean_bundle_df["bundle_id"]==id_]["genre"]:
#             for genre in genres.split(","):
#                 if genre not in words:
#                     words = words + genre + " "
            for genre in genres.split(", "):
                if genre not in genres_list:
                    genres_list.append(genre)
        filter_genre_from_bundle[id_] = genres_list
        
    return filter_genre_from_bundle

# %%
perform_data_preprocessing()

# %%
steam_games_df.head()
# Out:
#              publisher                                             genres  \
# 0            Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1     Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2         Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                 彼岸领域                        [Action, Adventure, Casual]
# 5  Trickjump Games Ltd                    [Action, Adventure, Simulation]
#
#                      title                                                url  \
# 0      Lost Summoner Kitty  http://store.steampowered.com/app/761140/Lost_...
# 1                Ironbound  http://store.steampowered.com/app/643980/Ironb...
# 2  Real Pool 3D - Poolians  http://store.steampowered.com/app/670290/Real_...
# 3                  弹炸人2222     http://store.steampowered.com/app/767400/2222/
# 5    Battle Royale Trainer  http://store.steampowered.com/app/772540/Battl...
#
#   release_date  discount_price  \
# 0   2018-01-04            4.49
# 1   2018-01-04             NaN
# 2   2017-07-24             NaN
# 3   2017-12-07            0.83
# 5   2018-01-04             NaN
#
#                                          reviews_url  \
# 0  http://steamcommunity.com/app/761140/reviews/?...
# 1  http://steamcommunity.com/app/643980/reviews/?...
# 2  http://steamcommunity.com/app/670290/reviews/?...
# 3  http://steamcommunity.com/app/767400/reviews/?...
# 5  http://steamcommunity.com/app/772540/reviews/?...
#
#                                                specs         price  \
# 0                                    [Single-player]          4.99
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                    [Single-player]          0.99
# 5                [Single-player, Steam Achievements]          3.99
#
#    early_access      id            developer        sentiment
# 0         False  761140            Kotoshiro              NaN
# 1         False  643980     Secret Level SRL  Mostly Positive
# 2         False  670290         Poolians.com  Mostly Positive
# 3         False  767400                 彼岸领域              NaN
# 5         False  772540  Trickjump Games Ltd            Mixed

# %%
all_bundles_genres_data = extract_genres_data_from_bundles()

# %%
filtered_playtime_df = filter_by_playtime('76561197970982479', 30)

# %% [markdown]
# # Recommend bundle to user based on most played genres

# %%
def get_all_genres_by_user(user):
    genre_count = {}
    for index, row in user.iterrows():
        if steam_games_df[steam_games_df["id"]==row["item_id"]].index.any()==True:
            game_genres = steam_games_df[steam_games_df["id"]==row["item_id"]]["genres"].values[0]
            for genre in game_genres:
                if genre not in genre_count:
                    genre_count[genre] = 1
                else:
                    genre_count[genre] = genre_count[genre] + 1

    return sorted(genre_count.items(), key=operator.itemgetter(1), reverse=True)

# %%
def parse_genres(genres):
#     g = ""
    lst = []
    for genre in genres[:math.ceil(len(genres)*.75)]:
#         g = g + genre[0] + " "
        lst.append(genre[0])
    return lst

# %%
def get_bundle_similarity_scores(user_genres, all_bundles_genres_data):
    sim = {}
#     ug = word_tokenize(user_genres)
    
    for id_ in list(all_bundles_genres_data.keys()):
        bundle_genres = all_bundles_genres_data[id_]

        lst1 = []
        lst2 = []
        cos = 0
        vector = list(set().union(user_genres, bundle_genres))
        for i in vector:
            if i in user_genres:
                lst1.append(1)
            else:
                lst1.append(0)
                
            if i in bundle_genres:
                lst2.append(1)
            else:
                lst2.append(0)
            cos += lst1[-1]*lst2[-1]

        sim[id_] = cos / float((sum(lst1)*sum(lst2))**0.5)
    
    return sorted(sim.items(), key=operator.itemgetter(1), reverse=True)

# %%
all_user_genres = get_all_genres_by_user(filtered_playtime_df)

# %%
top_rated_genres = parse_genres(all_user_genres)

# %%
sim = get_bundle_similarity_scores(top_rated_genres, all_bundles_genres_data)

# %%
sim
# Out:
# [('803', 0.9428090415820635),
#  ('813', 0.9428090415820635),
#  ('580', 0.8888888888888888),
#  ('948', 0.8888888888888888),
#  ('396', 0.8819171036881969),
#  ('505', 0.8819171036881969),
#  ('364', 0.8819171036881969),
#  ('399', 0.8819171036881969),
#  ('482', 0.8819171036881969),
#  ('957', 0.8819171036881969),
#  ('802', 0.8819171036881969),
#  ('804', 0.8819171036881969),
#  ('403', 0.8819171036881969),
#  ('395', 0.8819171036881969),
#  ('542', 0.8819171036881969),
#  ('356', 0.8819171036881969),
#  ('268', 0.8432740427115678),
#  ('808', 0.8249579113843055),
#  ('833', 0.8249579113843055),
#  ('425', 0.8249579113843055),
#  ('663', 0.8249579113843055),
#  ('225', 0.8249579113843055),
#  ('565', 0.8249579113843055),
#  ('1437', 0.816496580927726),
#  ('1441', 0.816496580927726),
#  ('501', 0.816496580927726),
#  ('801', 0.816496580927726),
#  ('1206', 0.816496580927726),
#  ('1143', 0.816496580927726),
#  ('398', 0.816496580927726),
#  ('824', 0.816496580927726),
#  ('569', 0.816496580927726),
#  ('646', 0.816496580927726),
#  ('746', 0.816496580927726),
#  ('623', 0.816496580927726),
#  ('332', 0.816496580927726),
#  ('339', 0.816496580927726),
#  ('432', 0.816496580927726),
#  ('436', 0.816496580927726),
#  ('269', 0.47140452079103173),
#  ('270', 0.47140452079103173),
#  ('273', 0.47140452079103173),
#  ('278', 0.47140452079103173),
#  ('306', 0.47140452079103173),
#  ('313', 0.47140452079103173),
#  ('316', 0.47140452079103173),
#  ('366', 0.47140452079103173),
#  ('367', 0.47140452079103173),
#  ('375', 0.47140452079103173),
#  ('381', 0.47140452079103173),
#  ('391', 0.47140452079103173),
#  ('408', 0.47140452079103173),
#  ('409', 0.47140452079103173),
#  ('438', 0.47140452079103173),
#  ('451', 0.47140452079103173),
#  ('471', 0.47140452079103173),
#  ('495', 0.47140452079103173),
#  ('497', 0.47140452079103173),
#  ('519', 0.47140452079103173),
#  ('579', 0.47140452079103173),
#  ('581', 0.47140452079103173),
#  ('582', 0.47140452079103173),
#  ('584', 0.47140452079103173),
#  ('251', 0.4472135954999579),
#  ('628', 0.4472135954999579),
#  ('321', 0.4444444444444444),
#  ('355', 0.3849001794597505),
#  ('1409', 0.3849001794597505),
#  ('1355', 0.3849001794597505),
#  ('1156', 0.3849001794597505),
#  ('479', 0.3849001794597505),
#  ('1013', 0.3849001794597505),
#  ('1024', 0.3849001794597505),
#  ('683', 0.3849001794597505),
#  ('247', 0.3849001794597505),
#  ('349', 0.3849001794597505),
#  ('1471', 0.3333333333333333),
#  ('1379', 0.3333333333333333),
#  ('1293', 0.3333333333333333),
#  ('1248', 0.3333333333333333),
#  ('1271', 0.3333333333333333),
#  ('363', 0.3333333333333333),
#  ('1002', 0.3333333333333333),
#  ('359', 0.3333333333333333),
#  ('809', 0.3333333333333333),
#  ('548', 0.3333333333333333),
#  ('353', 0.3333333333333333),
#  ('1247', 0.3333333333333333),
#  ('1243', 0.3333333333333333),
#  ('951', 0.3333333333333333),
#  ('1241', 0.3333333333333333),
#  ('1028', 0.3333333333333333),
#  ('1158', 0.3333333333333333),
#  ('872', 0.3333333333333333),
#  ('1103', 0.3333333333333333),
#  ('709', 0.3333333333333333),
#  ('1128', 0.3333333333333333),
#  ('962', 0.3333333333333333),
#  ('575', 0.3333333333333333),
#  ('543', 0.3333333333333333),
#  ('624', 0.3333333333333333),
#  ('701', 0.3333333333333333),
#  ('861', 0.3333333333333333),
#  ('859', 0.3333333333333333),
#  ('755', 0.3333333333333333),
#  ('574', 0.3333333333333333),
#  ('635', 0.3333333333333333),
#  ('627', 0.3333333333333333),
#  ('612', 0.3333333333333333),
#  ('231', 0.3333333333333333),
#  ('233', 0.3333333333333333),
#  ('235', 0.3333333333333333),
#  ('236', 0.3333333333333333),
#  ('237', 0.3333333333333333),
#  ('240', 0.3333333333333333),
#  ('254', 0.3333333333333333),
#  ('258', 0.3333333333333333),
#  ('263', 0.3333333333333333),
#  ('303', 0.3333333333333333),
#  ('311', 0.3333333333333333),
#  ('320', 0.3333333333333333),
#  ('354', 0.3333333333333333),
#  ('361', 0.3333333333333333),
#  ('417', 0.3333333333333333),
#  ('571', 0.3333333333333333),
#  ('1225', 0.23570226039551587),
#  ('1268', 0.23570226039551587),
#  ('1009', 0.23570226039551587),
#  ('249', 0.23570226039551587),
#  ('333', 0.23570226039551587),
#  ('916', 0.0),
#  ('917', 0.0),
#  ('456', 0.0),
#  ('1003', 0.0),
#  ('678', 0.0),
#  ('546', 0.0),
#  ('227', 0.0),
#  ('228', 0.0),
#  ('229', 0.0),
#  ('230', 0.0),
#  ('318', 0.0),
#  ('322', 0.0),
#  ('342', 0.0),
#  ('376', 0.0),
#  ('377', 0.0),
#  ('491', 0.0),
#  ('492', 0.0)]

# %%
def get_bundle_recommendations(user_id, num_recommendations, sim, bundle_data=bundle_data):
    
    recommendations = []
    for id_ in sim[:num_recommendations]:
        for bundle in bundle_data:
            if bundle["bundle_id"]==id_[0]:
                recommendations.append(bundle)
                break
    
    return recommendations

# %%
recommendations = get_bundle_recommendations('76561197970982479', 3, sim)

# %%
recommendations
# Out:
# [{'bundle_final_price': '$4.87',
#   'bundle_url': 'http://store.steampowered.com/bundle/803/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$32.41',
#   'bundle_name': 'Platformer Bundle',
#   'bundle_id': '803',
#   'items': [{'genre': 'Action, Adventure, Indie, Simulation, Strategy',
#     'item_id': '104200',
#     'discounted_price': '$0.49',
#     'item_url': 'http://store.steampowered.com/app/104200',
#     'item_name': 'BEEP'},
#    {'genre': 'Action, Adventure, Indie, Simulation, Strategy',
#     'item_id': '263980',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/263980',
#     'item_name': 'Out There Somewhere'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '317250',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/317250',
#     'item_name': 'Airscape - The Fall of Gravity'},
#    {'genre': 'Action, Adventure, Casual, Indie',
#     'item_id': '341500',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/341500',
#     'item_name': 'Camera Obscura'},
#    {'genre': 'Adventure, Casual, Indie, RPG',
#     'item_id': '351150',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/351150',
#     'item_name': 'DRAGON: A Game About a Dragon'},
#    {'genre': 'Action, Adventure, Indie, Simulation, Strategy',
#     'item_id': '371670',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/371670',
#     'item_name': 'Rolling Sun'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '394540',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/394540',
#     'item_name': 'Spaceport Hope'},
#    {'genre': 'Casual, Indie, Simulation, Sports',
#     'item_id': '396360',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/396360',
#     'item_name': 'LocoSoccer'},
#    {'genre': 'Action, Adventure, Indie, Strategy',
#     'item_id': '429700',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/429700',
#     'item_name': 'Squirbs'}],
#   'bundle_discount': '85%'},
#  {'bundle_final_price': '$14.70',
#   'bundle_url': 'http://store.steampowered.com/bundle/813/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$73.26',
#   'bundle_name': 'The Big One',
#   'bundle_id': '813',
#   'items': [{'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '204180',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/204180',
#     'item_name': 'Waveform'},
#    {'genre': 'Action, Adventure, Indie, Simulation, Strategy',
#     'item_id': '263980',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/263980',
#     'item_name': 'Out There Somewhere'},
#    {'genre': 'Action, Adventure, Indie, RPG, Simulation, Strategy',
#     'item_id': '274560',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/274560',
#     'item_name': 'Revolution Ace'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation',
#     'item_id': '291010',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/291010',
#     'item_name': 'The Hat Man: Shadow Ward'},
#    {'genre': 'Action, Adventure, Casual, Indie, Strategy',
#     'item_id': '295690',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/295690',
#     'item_name': 'PARTICLE MACE'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Sports, Strategy',
#     'item_id': '306040',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/306040',
#     'item_name': 'The Howler'},
#    {'genre': 'Action, Adventure, Casual, Indie, Simulation, Strategy',
#     'item_id': '314020',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/314020',
#     'item_name': 'Morphopolis'},
#    {'genre': 'Action, Adventure, Indie, RPG, Strategy',
#     'item_id': '314450',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/314450',
#     'item_name': 'Star Saviors'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '317250',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/317250',
#     'item_name': 'Airscape - The Fall of Gravity'},
#    {'genre': 'Action, Adventure, Casual, Indie, Strategy',
#     'item_id': '340070',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/340070',
#     'item_name': 'Battle Ranch: Pigs vs Plants'},
#    {'genre': 'Adventure, Casual, Indie, RPG',
#     'item_id': '351150',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/351150',
#     'item_name': 'DRAGON: A Game About a Dragon'},
#    {'genre': 'Action, Casual, Indie, Strategy',
#     'item_id': '351490',
#     'discounted_price': '$0.49',
#     'item_url': 'http://store.steampowered.com/app/351490',
#     'item_name': 'Intergalactic Bubbles'},
#    {'genre': 'Action, Adventure, Indie, Simulation, Strategy',
#     'item_id': '371670',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/371670',
#     'item_name': 'Rolling Sun'},
#    {'genre': 'Action, Indie, RPG',
#     'item_id': '380020',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/380020',
#     'item_name': 'Three Heroes'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Strategy',
#     'item_id': '391260',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/391260',
#     'item_name': 'Labyronia RPG'},
#    {'genre': 'Action, Adventure, Indie, Strategy',
#     'item_id': '391420',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/391420',
#     'item_name': 'Gun Rocket'},
#    {'genre': 'Action, Adventure, Indie',
#     'item_id': '394540',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/394540',
#     'item_name': 'Spaceport Hope'},
#    {'genre': 'Casual, Indie, Simulation, Sports',
#     'item_id': '396360',
#     'discounted_price': '$0.99',
#     'item_url': 'http://store.steampowered.com/app/396360',
#     'item_name': 'LocoSoccer'},
#    {'genre': 'Action, Adventure, Indie, RPG, Strategy',
#     'item_id': '397500',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/397500',
#     'item_name': 'Labyronia RPG 2'},
#    {'genre': 'Action, Adventure, Casual, Indie, RPG, Strategy',
#     'item_id': '407230',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/407230',
#     'item_name': 'Legend of Mysteria RPG'},
#    {'genre': 'Action, Adventure, Indie, Strategy',
#     'item_id': '429700',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/429700',
#     'item_name': 'Squirbs'},
#    {'genre': 'Adventure, Indie, RPG',
#     'item_id': '434420',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/434420',
#     'item_name': 'The Chosen RPG'},
#    {'genre': 'Adventure, Indie, RPG',
#     'item_id': '461640',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/461640',
#     'item_name': 'Sins Of The Demon RPG'},
#    {'genre': 'Adventure, RPG, Strategy',
#     'item_id': '463350',
#     'discounted_price': '$1.99',
#     'item_url': 'http://store.steampowered.com/app/463350',
#     'item_name': 'Storm Of Spears RPG'}],
#   'bundle_discount': '80%'},
#  {'bundle_final_price': '$9.02',
#   'bundle_url': 'http://store.steampowered.com/bundle/580/?utm_source=SteamDB&utm_medium=SteamDB&utm_campaign=SteamDB%20Bundles%20Page',
#   'bundle_price': '$36.03',
#   'bundle_name': 'FE Ultimate Bundle',
#   'bundle_id': '580',
#   'items': [{'genre': 'Adventure, Indie',
#     'item_id': '257830',
#     'discounted_price': '$9.99',
#     'item_url': 'http://store.steampowered.com/app/257830',
#     'item_name': 'Violett Remastered'},
#    {'genre': 'Adventure, Indie, RPG, Simulation, Strategy',
#     'item_id': '294020',
#     'discounted_price': '$1.49',
#     'item_url': 'http://store.steampowered.com/app/294020',
#     'item_name': 'Merchants of Kaidan'},
#    {'genre': 'Action, Casual, Indie',
#     'item_id': '294230',
#     'discounted_price': '$0.51',
#     'item_url': 'http://store.steampowered.com/app/294230',
#     'item_name': 'Millie'},
#    {'genre': 'Action, Casual, Indie',
#     'item_id': '301190',
#     'discounted_price': '$2.99',
#     'item_url': 'http://store.steampowered.com/app/301190',
#     'item_name': 'Frederic: Resurrection of Music'},
#    {'genre': 'Adventure, Casual, Indie',
#     'item_id': '340300',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/340300',
#     'item_name': 'Teddy Floppy Ear - Mountain Adventure'},
#    {'genre': 'Adventure, Casual, Indie',
#     'item_id': '340310',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/340310',
#     'item_name': 'Teddy Floppy Ear - Kayaking'},
#    {'genre': 'Indie, Racing, Simulation, Sports',
#     'item_id': '371420',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/371420',
#     'item_name': 'Teddy Floppy Ear - The Race'},
#    {'genre': 'Adventure, Casual, Indie, RPG, Simulation, Strategy',
#     'item_id': '375460',
#     'discounted_price': '$0.50',
#     'item_url': 'http://store.steampowered.com/app/375460',
#     'item_name': '16bit Trader'},
#    {'genre': 'Action, Casual, Indie',
#     'item_id': '453100',
#     'discounted_price': '$0.59',
#     'item_url': 'http://store.steampowered.com/app/453100',
#     'item_name': "Frederic: Resurrection of Music Director's Cut"},
#    {'genre': 'Action, Casual, Indie',
#     'item_id': '456810',
#     'discounted_price': '$4.99',
#     'item_url': 'http://store.steampowered.com/app/456810',
#     'item_name': 'Zombillie'}],
#   'bundle_discount': '75%'}]

# %% [markdown]
# # Group Generation and Recommendation

# %%
def group_generation(user_id, num_of_users):
    user_data = {}
    
    for user in users_items:
        if user["user_id"]==user_id:
            user_data = user
            break
            
    filtered_df = json_normalize(user_data, "items", ["user_id", "steam_id", "user_url"])
    filtered_df = filtered_df[filtered_df["playtime_forever"] > 100]
    
    genres = get_all_genres_by_user(filtered_df)
    top_rated_genres = parse_genres(genres)
#     print(genres)
#     print(top_rated_genres)
    sim = {}
#     ug = word_tokenize(top_rated_genres)
    counter = 0
    
    np.random.shuffle(users_items)
    for user in users_items:
        if user["user_id"]!=user_id:
            user_df = json_normalize(user, "items", ["user_id", "steam_id", "user_url"])
            g = get_all_genres_by_user(user_df)
            parsed_genres = parse_genres(g)
#             tokens = word_tokenize(parsed_genres)
            
            lst1 = []
            lst2 = []
            cos = 0
            vector = list(set().union(top_rated_genres, parsed_genres))
            for i in vector:
                if i in top_rated_genres:
                    lst1.append(1)
                else:
                    lst1.append(0)

                if i in parsed_genres:
                    lst2.append(1)
                else:
                    lst2.append(0)
                cos += lst1[-1]*lst2[-1]
            
            if float((sum(lst1)*sum(lst2))**0.5)==0:
                continue
                
            cos = cos / float((sum(lst1)*sum(lst2))**0.5)
            if cos >= 0.75:
                counter += 1
                sim[user["user_id"]] = cos
                
            if counter == num_of_users:
                break
                    
                
    return sorted(sim, key=operator.itemgetter(1), reverse=True), top_rated_genres

# %%
user_group, top_genres = group_generation('76561197970982479', 100)

# %%
user_group
# Out:
# ['My_Special_Place',
#  'hybrid905',
#  'Dythoras',
#  'Uve-Seen_Nothing',
#  'kummaz',
#  'julezislive',
#  'cronix0',
#  'SpicyHolo',
#  'zoobark',
#  'lowanalawliet',
#  'loadsamoney',
#  'Torca2001',
#  'potternerd',
#  'Toothless_Agression',
#  'anykylator',
#  'flippylejeff',
#  'okaygetrektscrub',
#  'KiritoNZ',
#  'niconicolii',
#  'nicolasbrendo',
#  'DidiKong',
#  'shez13',
#  'TheZomyo',
#  'Aesirn',
#  'Sentinel07',
#  'Zeuaireus',
#  'Deathjester96',
#  'dekruz',
#  'Kaka1800',
#  'davo27',
#  'dagster_007',
#  'hammyhamm',
#  'galasal',
#  'Lamus',
#  'Kaspa',
#  'pandasmokingbamboo',
#  'xScrivz',
#  'LOLBITCHS',
#  'FORTHMINGUTH',
#  'ANIMEPUSSY',
#  'ABSOLUTLY_NOTHING',
#  '76561198078883335',
#  '76561198000881087',
#  '76561198095847205',
#  '76561198068601332',
#  '76561198040814960',
#  '76561197989918287',
#  '76561198087011672',
#  '76561198090345356',
#  '76561198078580381',
#  '76561198046023819',
#  '76561198027481760',
#  '76561198079350354',
#  '76561198064735291',
#  '76561198030858298',
#  '76561198039606680',
#  '76561198058406533',
#  '76561198006894551',
#  '76561198301529231',
#  '76561198031328620',
#  '76561198043779241',
#  '76561198073484097',
#  '76561198062556071',
#  '76561198094834382',
#  '76561198057414589',
#  '76561197996383185',
#  '76561198078874982',
#  '76561198088502466',
#  '76561198047414375',
#  '76561197966298550',
#  '76561198049698789',
#  '76561197998888551',
#  '76561198050050362',
#  '76561198042400108',
#  '76561198022704114',
#  '76561198011707963',
#  '76561198085820571',
#  '76561198082569416',
#  '76561198206561980',
#  '76561198045151908',
#  '76561197991249235',
#  '76561198077805024',
#  '76561198078913614',
#  '76561198012131121',
#  '76561198003522410',
#  '76561198026055531',
#  '76561198158674140',
#  '76561198074644154',
#  '76561198120726751',
#  '76561198072472534',
#  '76561198070365440',
#  '76561198026262441',
#  '76561198007538539',
#  '76561198079584462',
#  '76561198096755376',
#  '76561198071478380',
#  '76561198094349676',
#  '76561198091999396',
#  '76561198007165405',
#  '76561198005698927']

# %%
def get_multiplayer_games(steam_games):
    games = steam_games.copy()
    
    for i, row in games.iterrows():
        flag = False
        if type(row["specs"]) != list:
            games.drop([i], inplace=True)
            continue
            
        for spec in row["specs"]:
            if spec=="Online Multi-Player":
                flag = True
                break
                
        if flag==False:
            games.drop([i], inplace=True)
            
    games.reset_index(inplace=True)
    games["discount_price"].fillna(0, inplace=True)
    games["price"].fillna(0, inplace=True)
            
    return games

# %%
multiplayer_games = get_multiplayer_games(steam_games_df)

# %%
def get_most_similar_games(games, user_group, top_genres, num_of_games):
    sim = {}
    for i, row in games.iterrows():
        game_genres = row["genres"]
        
        lst1 = []
        lst2 = []
        cos = 0
        vector = list(set().union(top_genres, game_genres))
        for i in vector:
            if i in top_genres:
                lst1.append(1)
            else:
                lst1.append(0)
            if i in game_genres:
                lst2.append(1)
            else:
                lst2.append(0)
            cos += lst1[-1]*lst2[-1]
            
        if float((sum(lst1)*sum(lst2))**0.5)==0:
            continue
                
        sim[row["id"]] = cos / float((sum(lst1)*sum(lst2))**0.5)
    
    sim = sorted(sim.items(), key=operator.itemgetter(1), reverse=True)
    
    games_list = []
    for i in sim[:num_of_games]:
        games_list.append(i[0])
        
    return games_list

# %%
list_of_games = get_most_similar_games(multiplayer_games, user_group, top_genres, 10)

# %%
list_of_games
# Out:
# ['413120',
#  '666600',
#  '515710',
#  '638180',
#  '462440',
#  '254200',
#  '434380',
#  '366690',
#  '562700',
#  '582660']

# %%
def bundle_generation(games):
    bundle = {}
    bundle["name"] = "Made just for you"
    bundle["items"] = []
    discounted_total = 0
    total_price = 0
    for id_ in games:
        game = multiplayer_games[multiplayer_games["id"]==id_]
        
        item_info = {}
        item_info["item_id"] = id_
        item_info["genre"] = ', '.join(map(str, game["genres"].values[0]))
        item_info["name"] = game["title"].values[0]
        
        if type(game["price"]) != str:
            total_price += game["price"].values[0]
        
        discounted_total += game["discount_price"].values[0]
        
        bundle["items"].append(item_info)
    
    bundle["bundle_final_price"] = total_price - discounted_total
    
    return bundle

# %%
bundle = bundle_generation(list_of_games)

# %%
bundle
# Out:
# {'name': 'Made just for you',
#  'items': [{'item_id': '413120',
#    'genre': 'Action, Casual, Indie, Massively Multiplayer, Simulation, Sports, Strategy',
#    'name': 'Tactics Forever'},
#   {'item_id': '666600',
#    'genre': 'Action, Adventure, Casual, Indie, RPG, Simulation, Strategy',
#    'name': 'Zombie Town'},
#   {'item_id': '515710',
#    'genre': 'Action, Adventure, Casual, Free to Play, Indie, Massively Multiplayer, RPG, Simulation',
#    'name': 'Creativerse - Pro'},
#   {'item_id': '638180',
#    'genre': 'Action, Adventure, Casual, Free to Play, Indie, Massively Multiplayer, RPG, Simulation',
#    'name': 'Creativerse - Welcome Bundle'},
#   {'item_id': '462440',
#    'genre': 'Action, Adventure, Indie, Massively Multiplayer, RPG, Simulation, Strategy, Early Access',
#    'name': 'ROKH'},
#   {'item_id': '254200',
#    'genre': 'Adventure, Casual, Indie, RPG, Simulation, Strategy',
#    'name': 'FortressCraft Evolved!'},
#   {'item_id': '434380',
#    'genre': 'Action, Adventure, Casual, Indie, Massively Multiplayer, Simulation',
#    'name': 'Pixel Z - Gun Day'},
#   {'item_id': '366690',
#    'genre': 'Action, Casual, Indie, Simulation, Sports, Strategy',
#    'name': 'Cue Club 2: Pool &amp; Snooker'},
#   {'item_id': '562700',
#    'genre': 'Action, Casual, Indie, Massively Multiplayer, Simulation, Sports',
#    'name': 'Paintball 707'},
#   {'item_id': '582660',
#    'genre': 'Action, Adventure, Massively Multiplayer, RPG, Simulation, Strategy',
#    'name': 'Black Desert Online'}],
#  'bundle_final_price': 104.90999999999997}
